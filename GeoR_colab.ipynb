# %% [markdown]
# # Analisando dados a partir do GEO, usando R/Colab
#
# **Observações:**
#
# - Este notebook foi adaptado para o português brasileiro a partir do tutorial descrito por Mark Dunning, versão original disponível [AQUI](https://sbc.shef.ac.uk/geo_tutorial/tutorial.nb.html). Qualquer citação deve ser direcionada ao tutorial original.
# - A reprodução sem a citação ao tutorial/autor principal não é permitida.

# %% [markdown]
# ## Introdução
#
# Neste tutorial, demonstraremos como baixar dados do *Gene Expression Omnibus* diretamente no R. Uma vez carregados, realizaremos algumas avaliações de qualidade, expressão diferencial e análises subsequentes, como agrupamento. Os grupos de dados ou séries devem ter sido geradas por *microarrays*. Para dados de transcriptoma por RNA-Seq, utilize esse [Tutorial](https://bioinformatics-core-shared-training.github.io/RNAseq-R/).
#
# Ilustraremos as principais etapas do fluxo de trabalho. No entanto, algumas etapas podem precisar ser ajustadas para sua análise específica (por exemplo, alterando o modelo para a expressão diferencial).
#
# > **ATENÇÃO:**
# >
# >*Este notebook foi feito para que as células sejam executadas individualmente. Nunca execute tudo, pois algumas etapas são opcionais, dependendo dos seus dados. Os comandos opcionais foram comentados para evitar execução não intencional. Leia todo o texto antes de executar cada célula de código.*

# %% [markdown]
# ### Instalando os pacotes necessários:
#
# A instalação é um pouco demorada (cerca de 20 min.), mas as análises são relativamente rápidas. O ambiente R do Colab já vem com vários pacotes padrões instalados, inclusive com alguns que iremos precisar aqui. Se você desejar que a instalação seja mais rápida, execute o comando `library()`, verifique as bibliotecas que já existem e comente as linhas relativas à sua instalação na célula abaixo.

# %%
install.packages("BiocManager")
install.packages("forcats")
install.packages("stringr")
install.packages("ggplot2")
install.packages("ggrepel")
install.packages("readr")
install.packages("tidyr")
install.packages("survminer")
BiocManager::install("GEOquery")
BiocManager::install("limma")
BiocManager::install("pheatmap")
BiocManager::install("org.Hs.eg.db")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependency ‘Rcpp’
#
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘numDeriv’, ‘SparseM’, ‘MatrixModels’, ‘minqa’, ‘nloptr’, ‘RcppEigen’, ‘carData’, ‘abind’, ‘pbkrtest’, ‘quantreg’, ‘lme4’, ‘corrplot’, ‘car’, ‘markdown’, ‘png’, ‘jpeg’, ‘ggsci’, ‘cowplot’, ‘ggsignif’, ‘polynom’, ‘rstatix’, ‘exactRankTests’, ‘mvtnorm’, ‘KMsurv’, ‘zoo’, ‘km.ci’, ‘xtable’, ‘gridtext’, ‘ggpubr’, ‘gridExtra’, ‘maxstat’, ‘survMisc’, ‘ggtext’
#
#
# 'getOption("repos")' replaces Bioconductor standard repositories, see
# 'help("repositories", package = "BiocManager")' for details.
# Replacement repositories:
#     CRAN: https://cran.rstudio.com
#
# Bioconductor version 3.19 (BiocManager 1.30.23), R 4.4.0 (2024-04-24)
#
# Installing package(s) 'BiocVersion', 'GEOquery'
#
# also installing the dependencies ‘BiocGenerics’, ‘statmod’, ‘R.oo’, ‘R.methodsS3’, ‘Biobase’, ‘limma’, ‘R.utils’
#
#
# Old packages: 'bit', 'brio', 'bslib', 'callr', 'curl', 'data.table', 'DBI',
#   'dbplyr', 'devtools', 'digest', 'fs', 'gargle', 'ggplot2', 'gh', 'gtable',
#   'highr', 'htmltools', 'httr2', 'isoband', 'knitr', 'munsell', 'openssl',
#   'pkgbuild', 'processx', 'ragg', 'remotes', 'rmarkdown', 'rstudioapi',
#   'rvest', 'sass', 'stringi', 'systemfonts', 'testthat', 'textshaping',
#   'tidyselect', 'tinytex', 'usethis', 'whisker', 'xfun', 'xopen', 'zip',
#   'codetools', 'lattice', 'MASS', 'Matrix', 'nlme', 'survival'
#
# 'getOption("repos")' replaces Bioconductor standard repositories, see
# 'help("repositories", package = "BiocManager")' for details.
# Replacement repositories:
#     CRAN: https://cran.rstudio.com
#
# Bioconductor version 3.19 (BiocManager 1.30.23), R 4.4.0 (2024-04-24)
#
# Warning message:
# “package(s) not installed when version(s) same as or greater than current; use
#   `force = TRUE` to re-install: 'limma'”
# Old packages: 'bit', 'brio', 'bslib', 'callr', 'curl', 'data.table', 'DBI',
#   'dbplyr', 'devtools', 'digest', 'fs', 'gargle', 'ggplot2', 'gh', 'gtable',
#   'highr', 'htmltools', 'httr2', 'isoband', 'knitr', 'munsell', 'openssl',
#   'pkgbuild', 'processx', 'ragg', 'remotes', 'rmarkdown', 'rstudioapi',
#   'rvest', 'sass', 'stringi', 'systemfonts', 'testthat', 'textshaping',
#   'tidyselect', 'tinytex', 'usethis', 'whisker', 'xfun', 'xopen', 'zip',
#   'codetools', 'lattice', 'MASS', 'Matrix', 'nlme', 'survival'
#
# 'getOption("repos")' replaces Bioconductor standard repositories, see
# 'help("repositories", package = "BiocManager")' for details.
# Replacement repositories:
#     CRAN: https://cran.rstudio.com
#
# Bioconductor version 3.19 (BiocManager 1.30.23), R 4.4.0 (2024-04-24)
#
# Installing package(s) 'pheatmap'
#
# Old packages: 'bit', 'brio', 'bslib', 'callr', 'curl', 'data.table', 'DBI',
#   'dbplyr', 'devtools', 'digest', 'fs', 'gargle', 'ggplot2', 'gh', 'gtable',
#   'highr', 'htmltools', 'httr2', 'isoband', 'knitr', 'munsell', 'openssl',
#   'pkgbuild', 'processx', 'ragg', 'remotes', 'rmarkdown', 'rstudioapi',
#   'rvest', 'sass', 'stringi', 'systemfonts', 'testthat', 'textshaping',
#   'tidyselect', 'tinytex', 'usethis', 'whisker', 'xfun', 'xopen', 'zip',
#   'codetools', 'lattice', 'MASS', 'Matrix', 'nlme', 'survival'
#
# 'getOption("repos")' replaces Bioconductor standard repositories, see
# 'help("repositories", package = "BiocManager")' for details.
# Replacement repositories:
#     CRAN: https://cran.rstudio.com
#
# Bioconductor version 3.19 (BiocManager 1.30.23), R 4.4.0 (2024-04-24)
#
# Installing package(s) 'org.Hs.eg.db'
#
# also installing the dependencies ‘zlibbioc’, ‘UCSC.utils’, ‘GenomeInfoDbData’, ‘XVector’, ‘GenomeInfoDb’, ‘plogr’, ‘Biostrings’, ‘IRanges’, ‘RSQLite’, ‘S4Vectors’, ‘KEGGREST’, ‘AnnotationDbi’
#
#
# Old packages: 'bit', 'brio', 'bslib', 'callr', 'curl', 'data.table', 'DBI',
#   'dbplyr', 'devtools', 'digest', 'fs', 'gargle', 'ggplot2', 'gh', 'gtable',
#   'highr', 'htmltools', 'httr2', 'isoband', 'knitr', 'munsell', 'openssl',
#   'pkgbuild', 'processx', 'ragg', 'remotes', 'rmarkdown', 'rstudioapi',
#   'rvest', 'sass', 'stringi', 'systemfonts', 'testthat', 'textshaping',
#   'tidyselect', 'tinytex', 'usethis', 'whisker', 'xfun', 'xopen', 'zip',
#   'codetools', 'lattice', 'MASS', 'Matrix', 'nlme', 'survival'

# %% [markdown]
# ## Escolhendo o dado do *Gene Expression Series*
#
# Vamos supor que você já saiba o número de acesso (GSE) para o conjunto de dados que deseja baixar.
#
# A função para baixar um conjunto de dados GEO é `getGEO` do pacote `GEOquery`. Você precisa especificar o ID do conjunto de dados que deseja. Para baixar seus próprios dados, substitua GSE33126 pelo ID que lhe interessa.
#
# > *Não esqueça de trocar o acesso GSE, após a variável `my_id`.*

# %%
library(GEOquery)
## change my_id to be the dataset that you want.
my_id <- "GSE20602"
gse <- getGEO(my_id)
# Out:
# Loading required package: Biobase
#
# Loading required package: BiocGenerics
#
#
# Attaching package: ‘BiocGenerics’
#
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, aperm, append, as.data.frame, basename, cbind,
#     colnames, dirname, do.call, duplicated, eval, evalq, Filter, Find,
#     get, grep, grepl, intersect, is.unsorted, lapply, Map, mapply,
#     match, mget, order, paste, pmax, pmax.int, pmin, pmin.int,
#     Position, rank, rbind, Reduce, rownames, sapply, setdiff, table,
#     tapply, union, unique, unsplit, which.max, which.min
#
#
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Setting options('download.file.method.GEOquery'='auto')
#
# Setting options('GEOquery.inmemory.gpl'=FALSE)
#
# Found 1 file(s)
#
# GSE20602_series_matrix.txt.gz

# %% [markdown]
# Alguns conjuntos de dados no GEO podem ser derivados de diferentes plataformas de *microarray*. Portanto, o objeto gse é uma lista de diferentes conjuntos de dados. Você pode descobrir quantos foram usados verificando o comprimento do objeto gse. Geralmente, haverá apenas uma plataforma e o conjunto de dados que queremos analisar será o primeiro objeto na lista (gse[[1]]).

# %% [markdown]
# #### Checando as plataformas que foram utilizadas:

# %%
length(gse)
# Out:
# [1] 1

# %% [markdown]
# ### Escolhendo uma ou mais plataformas:

# %%
gse <- gse[[1]]
gse
## if more than one dataset is present, you can analyse the other dataset by changing the number inside the [[...]]
## e.g. gse <- gse[[2]]
# Out:
# ExpressionSet (storageMode: lockedEnvironment)
# assayData: 22283 features, 18 samples
#   element names: exprs
# protocolData: none
# phenoData
#   sampleNames: GSM517355 GSM517356 ... GSM517372 (18 total)
#   varLabels: title geo_accession ... tissue:ch1 (35 total)
#   varMetadata: labelDescription
# featureData
#   featureNames: 1007_s_at 1053_at ... AFFX-TrpnX-M_at (22283 total)
#   fvarLabels: ID GB_ACC ... Gene Ontology Molecular Function (16 total)
#   fvarMetadata: Column Description labelDescription
# experimentData: use 'experimentData(object)'
#   pubMedIds: 20019191
# Annotation: GPL96

# %% [markdown]
# #### Obtendo informações sobre o estudo:
#
# Informação das Amostras

# %%
pData(gse) ## print the sample information
# Out:
#           title        geo_accession status                submission_date
# GSM517355 NSC1         GSM517355     Public on Mar 30 2010 Mar 02 2010
# GSM517356 NSC2         GSM517356     Public on Mar 30 2010 Mar 02 2010
# GSM517357 NSC4         GSM517357     Public on Mar 30 2010 Mar 02 2010
# GSM517358 NSC5         GSM517358     Public on Mar 30 2010 Mar 02 2010
# GSM517359 NSC6         GSM517359     Public on Mar 30 2010 Mar 02 2010
# GSM517360 NSC7         GSM517360     Public on Mar 30 2010 Mar 02 2010
# GSM517361 NSC8         GSM517361     Public on Mar 30 2010 Mar 02 2010
# GSM517362 NSC11        GSM517362     Public on Mar 30 2010 Mar 02 2010
# GSM517363 NSC12        GSM517363     Public on Mar 30 2010 Mar 02 2010
# GSM517364 NSC13        GSM517364     Public on Mar 30 2010 Mar 02 2010
# GSM517365 NSC14        GSM517365     Public on Mar 30 2010 Mar 02 2010
# GSM517366 NSC15        GSM517366     Public on Mar 30 2010 Mar 02 2010
# GSM517367 NSC16        GSM517367     Public on Mar 30 2010 Mar 02 2010
# GSM517368 NSC18        GSM517368     Public on Mar 30 2010 Mar 02 2010
# GSM517369 TN1b-control GSM517369     Public on Mar 30 2010 Mar 02 2010
# GSM517370 TN2b-control GSM517370     Public on Mar 30 2010 Mar 02 2010
# GSM517371 TN3b-control GSM517371     Public on Mar 30 2010 Mar 02 2010
# GSM517372 TN4b-control GSM517372     Public on Mar 30 2010 Mar 02 2010
#           last_update_date type channel_count
# GSM517355 Mar 16 2010      RNA  1
# GSM517356 Mar 16 2010      RNA  1
ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM517nnn/GSM517360/suppl/GSM517360_GLOM-HGU133A-NSC7.CEL.gz
# GSM517361 ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM517nnn/GSM517361/suppl/GSM517361_GLOM-HGU133A-NSC8.CEL.gz
# GSM517362 ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM517nnn/GSM517362/suppl/GSM517362_GLOM-HGU133A-NSC11.CEL.gz
# GSM517363 ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM517nnn/GSM517363/suppl/GSM517363_GLOM-HGU133A-NSC12.CEL.gz
# GSM517364 ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM517nnn/GSM517364/suppl/GSM517364_GLOM-HGU133A-NSC13.CEL.gz
# GSM517365 ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM517nnn/GSM517365/suppl/GSM517365_GLOM-HGU133A-NSC14.CEL.gz
# GSM517366 ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM517nnn/GSM517366/suppl/GSM517366_GLOM-HGU133A-NSC15.CEL.gz
# GSM517367 ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM517nnn/GSM517367/suppl/GSM517367_GLOM-HGU133A-NSC16.CEL.gz
# GSM517368 ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM517nnn/GSM517368/suppl/GSM517368_GLOM-HGU133A-NSC18.CEL.gz
# GSM517369 ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM517nnn/GSM517369/suppl/GSM517369_GLOM-HGU133A-TN1b.CEL.gz
# GSM517370 ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM517nnn/GSM517370/suppl/GSM517370_GLOM-HGU133A-TN2b.CEL.gz
# GSM517371 ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM517nnn/GSM517371/suppl/GSM517371_GLOM-HGU133A-TN4b.CEL.gz
# GSM517372 ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM517nnn/GSM517372/suppl/GSM517372_GLOM-HGU133A-TN3b.CEL.gz
#           data_row_count disease state:ch1 tissue:ch1
# GSM517355 22283          nephrosclerosis   glomeruli of human kidney
# GSM517356 22283          nephrosclerosis   glomeruli of human kidney
# GSM517357 22283          nephrosclerosis   glomeruli of human kidney
# GSM517358 22283          nephrosclerosis   glomeruli of human kidney
# GSM517359 22283          nephrosclerosis   glomeruli of human kidney
# GSM517360 22283          nephrosclerosis   glomeruli of human kidney
# GSM517361 22283          nephrosclerosis   glomeruli of human kidney
# GSM517362 22283          nephrosclerosis   glomeruli of human kidney
# GSM517363 22283          nephrosclerosis   glomeruli of human kidney
# GSM517364 22283          nephrosclerosis   glomeruli of human kidney
# GSM517365 22283          nephrosclerosis   glomeruli of human kidney
# GSM517366 22283          nephrosclerosis   glomeruli of human kidney
# GSM517367 22283          nephrosclerosis   glomeruli of human kidney
# GSM517368 22283          nephrosclerosis   glomeruli of human kidney
# GSM517369 22283          control           glomeruli of human kidney
# GSM517370 22283          control           glomeruli of human kidney
# GSM517371 22283          control           glomeruli of human kidney
# GSM517372 22283          control           glomeruli of human kidney

# %% [markdown]
# Anotação dos genes:

# %%
fData(gse) ## print the gene annotation
# Out:
#                          ID                       GB_ACC    SPOT_ID
# 1007_s_at                1007_s_at                U48705
# 1053_at                  1053_at                  M87338
# 117_at                   117_at                   X51757
# 121_at                   121_at                   X69699
# 1255_g_at                1255_g_at                L36861
# 1294_at                  1294_at                  L13852
# 1316_at                  1316_at                  X55005
# 1320_at                  1320_at                  X79510
# 1405_i_at                1405_i_at                M21121
# 1431_at                  1431_at                  J02843
# 1438_at                  1438_at                  X75208
# 1487_at                  1487_at                  L38487
# 1494_f_at                1494_f_at                M33318
# 1598_g_at                1598_g_at                L13720
# 160020_at                160020_at                Z48481
# 1729_at                  1729_at                  L41690
# 1773_at                  1773_at                  L00635
# 177_at                   177_at                   U38545
# 179_at                   179_at                   U38980
# 1861_at                  1861_at                  U66879
# 200000_s_at              200000_s_at              NM_006445
# 200001_at                200001_at                NM_001749
# 200002_at                200002_at                NM_007209
# 200003_s_at              200003_s_at              NM_000991
# 200004_at                200004_at                NM_001418
# 200005_at                200005_at                NM_003753
# 200006_at                200006_at                NM_007262
# 200007_at                200007_at                NM_003134
# 200008_s_at              200008_s_at              D13988
# 200009_at                200009_at                NM_001494
# ⋮                        ⋮                        ⋮         ⋮
# AFFX-r2-Bs-lys-3_at      AFFX-r2-Bs-lys-3_at                --Control
# AFFX-r2-Bs-lys-5_at      AFFX-r2-Bs-lys-5_at                --Control
# AFFX-r2-Bs-lys-M_at      AFFX-r2-Bs-lys-M_at                --Control
# AFFX-r2-Bs-phe-3_at      AFFX-r2-Bs-phe-3_at                --Control
# AFFX-r2-Bs-phe-5_at      AFFX-r2-Bs-phe-5_at                --Control
# AFFX-r2-Bs-phe-M_at      AFFX-r2-Bs-phe-M_at                --Control
# AFFX-r2-Bs-thr-3_s_at    AFFX-r2-Bs-thr-3_s_at              --Control
# AFFX-r2-Bs-thr-5_s_at    AFFX-r2-Bs-thr-5_s_at              --Control
# AFFX-r2-Bs-thr-M_s_at    AFFX-r2-Bs-thr-M_s_at              --Control
# AFFX-r2-Ec-bioB-3_at     AFFX-r2-Ec-bioB-3_at               --Control
# AFFX-r2-Ec-bioB-5_at     AFFX-r2-Ec-bioB-5_at               --Control
# AFFX-r2-Ec-bioB-M_at     AFFX-r2-Ec-bioB-M_at               --Control
# AFFX-r2-Ec-bioC-3_at     AFFX-r2-Ec-bioC-3_at               --Control
# AFFX-r2-Ec-bioC-5_at     AFFX-r2-Ec-bioC-5_at               --Control
# AFFX-r2-Ec-bioD-3_at     AFFX-r2-Ec-bioD-3_at               --Control
# AFFX-r2-Ec-bioD-5_at     AFFX-r2-Ec-bioD-5_at               --Control
# AFFX-r2-Hs18SrRNA-3_s_at AFFX-r2-Hs18SrRNA-3_s_at           --Control
# AFFX-r2-Hs18SrRNA-5_at   AFFX-r2-Hs18SrRNA-5_at             --Control
# AFFX-r2-Hs18SrRNA-M_x_at AFFX-r2-Hs18SrRNA-M_x_at           --Control
# AFFX-r2-Hs28SrRNA-3_at   AFFX-r2-Hs28SrRNA-3_at             --Control
# AFFX-r2-Hs28SrRNA-5_at   AFFX-r2-Hs28SrRNA-5_at             --Control
# AFFX-r2-Hs28SrRNA-M_at   AFFX-r2-Hs28SrRNA-M_at             --Control
# AFFX-r2-P1-cre-3_at      AFFX-r2-P1-cre-3_at                --Control
# AFFX-r2-P1-cre-5_at      AFFX-r2-P1-cre-5_at                --Control
# AFFX-ThrX-3_at           AFFX-ThrX-3_at                     --Control
# AFFX-ThrX-5_at           AFFX-ThrX-5_at                     --Control
# AFFX-ThrX-M_at           AFFX-ThrX-M_at                     --Control
# AFFX-TrpnX-3_at          AFFX-TrpnX-3_at                    --Control
# AFFX-TrpnX-5_at          AFFX-TrpnX-5_at                    --Control
# AFFX-TrpnX-M_at          AFFX-TrpnX-M_at                    --Control
#                          Species Scientific Name Annotation Date
# 1007_s_at                Homo sapiens            Oct 6, 2014
3_at      Control sequence   Affymetrix Proprietary Database
# AFFX-r2-Bs-lys-5_at      Control sequence   Affymetrix Proprietary Database
# AFFX-r2-Bs-lys-M_at      Control sequence   Affymetrix Proprietary Database
# AFFX-r2-Bs-phe-3_at      Control sequence   Affymetrix Proprietary Database
# AFFX-r2-Bs-phe-5_at      Control sequence   Affymetrix Proprietary Database
# AFFX-r2-Bs-phe-M_at      Control sequence   Affymetrix Proprietary Database
# AFFX-r2-Bs-thr-3_s_at    Control sequence   Affymetrix Proprietary Database
# AFFX-r2-Bs-thr-5_s_at    Control sequence   Affymetrix Proprietary Database
# AFFX-r2-Bs-thr-M_s_at    Control sequence   Affymetrix Proprietary Database
# AFFX-r2-Ec-bioB-3_at     Control sequence   Affymetrix Proprietary Database
# AFFX-r2-Ec-bioB-5_at     Control sequence   Affymetrix Proprietary Database
# AFFX-r2-Ec-bioB-M_at     Control sequence   Affymetrix Proprietary Database
# AFFX-r2-Ec-bioC-3_at     Control sequence   Affymetrix Proprietary Database
# AFFX-r2-Ec-bioC-5_at     Control sequence   Affymetrix Proprietary Database
# AFFX-r2-Ec-bioD-3_at     Control sequence   Affymetrix Proprietary Database
# AFFX-r2-Ec-bioD-5_at     Control sequence   Affymetrix Proprietary Database
# AFFX-r2-Hs18SrRNA-3_s_at Control sequence   Affymetrix Proprietary Database
# AFFX-r2-Hs18SrRNA-5_at   Control sequence   Affymetrix Proprietary Database
# AFFX-r2-Hs18SrRNA-M_x_at Control sequence   Affymetrix Proprietary Database
# AFFX-r2-Hs28SrRNA-3_at   Control sequence   Affymetrix Proprietary Database
# AFFX-r2-Hs28SrRNA-5_at   Control sequence   Affymetrix Proprietary Database
# AFFX-r2-Hs28SrRNA-M_at   Control sequence   Affymetrix Proprietary Database
# AFFX-r2-P1-cre-3_at      Control sequence   Affymetrix Proprietary Database
# AFFX-r2-P1-cre-5_at      Control sequence   Affymetrix Proprietary Database
# AFFX-ThrX-3_at           Control sequence   Affymetrix Proprietary Database
# AFFX-ThrX-5_at           Control sequence   Affymetrix Proprietary Database
# AFFX-ThrX-M_at           Control sequence   Affymetrix Proprietary Database
# AFFX-TrpnX-3_at          Control sequence   Affymetrix Proprietary Database
# AFFX-TrpnX-5_at          Control sequence   Affymetrix Proprietary Database
# AFFX-TrpnX-M_at          Control sequence   Affymetrix Proprietary Database
#                          Target Description
# 1007_s_at                U48705 /FEATURE=mRNA /DEFINITION=HSU48705 Human receptor tyrosine kinase DDR gene, complete cds
# 1053_at                  M87338 /FEATURE= /DEFINITION=HUMA1SBU Human replication factor C, 40-kDa subunit (A1) mRNA, complete cds
# 117_at                   X51757 /FEATURE=cds /DEFINITION=HSP70B Human heat-shock protein HSP70B' gene
# 121_at                   X69699 /FEATURE= /DEFINITION=HSPAX8A H.sapiens Pax8 mRNA
# 1255_g_at                L36861 /FEATURE=expanded_cds /DEFINITION=HUMGCAPB Homo sapiens guanylate cyclase activating protein (GCAP) gene exons 1-4, complete cds
# 1294_at                  L13852 /FEATURE= /DEFINITION=HUME1URP Homo sapiens ubiquitin-activating enzyme E1 related protein mRNA, complete cds
# 1316_at                  X55005 /FEATURE=mRNA /DEFINITION=HSCERBAR Homo sapiens mRNA for thyroid hormone receptor alpha 1 THRA1, (c-erbA-1 gene)
# 1320_at                  X79510 /FEATURE=cds /DEFINITION=HSPTPD1 H.sapiens mRNA for protein-tyrosine-phosphatase D1
# 1405_i_at                M21121 /FEATURE= /DEFINITION=HUMTCSM Human T cell-specific protein (RANTES) mRNA, complete cds
# 1431_at                  J02843 /FEATURE=cds /DEFINITION=HUMCYPIIE Human cytochrome P450IIE1 (ethanol-inducible) gene, complete cds
# 1438_at                  X75208 /FEATURE=cds /DEFINITION=HSPTKR H.sapiens HEK2 mRNA for protein tyrosine kinase receptor
# 1487_at                  L38487 /FEATURE=mRNA /DEFINITION=HUMHERRA1 Human estrogen receptor-related protein (hERRa1) mRNA, 3' end, partial cds
# 1494_f_at                M33318 /FEATURE=mRNA /DEFINITION=HUMCPIIA3A Human cytochrome P450IIA3 (CYP2A3) mRNA, complete cds
# 1598_g_at                L13720 /FEATURE= /DEFINITION=HUMGAS Homo sapiens growth-arrest-specific protein (gas) mRNA, complete cds
# 160020_at                Z48481 /FEATURE=cds /DEFINITION=HSMMPM1 H.sapiens mRNA for membrane-type matrix metalloproteinase 1 /NOTE=replacement of probe set 1301_s_at
# 1729_at                  L41690 /FEATURE= /DEFINITION=HUMTRADD Homo sapiens TNF receptor-1 associated protein (TRADD) mRNA, 3' end of cds
# 1773_at                  L00635 /FEATURE= /DEFINITION=HUMFPTB Human farnesyl-protein transferase beta-subunit mRNA, complete cds
# 177_at                   U38545 /FEATURE= /DEFINITION=HSU38545 Human ARF-activated phosphatidylcholine-specific phospholipase D1a (hPLD1) mRNA, complete cds
# 179_at                   U38980 /FEATURE= /DEFINITION=U38980 Human PMS2 related (hPMSR6) mRNA,  complete cds
# 1861_at                  U66879 /FEATURE= /DEFINITION=HSU66879 Human Bcl-2 binding component 6 (bbc6) mRNA, complete cds
# 200000_s_at              gb:NM_006445.1 /DEF=Homo sapiens U5 snRNP-specific protein (220 kD), ortholog of S. cerevisiae Prp8
of gb:X17013.1, not 100% identical /DEF=B subtilis lys gene for diaminopimelate decarboxylase (EC 4.1.1.20).
# AFFX-r2-Bs-lys-5_at      B. subtilis /GEN=lys /DB_XREF=gb:X17013.1 /NOTE=SIF corresponding to nucleotides 411-659 of gb:X17013.1, not 100% identical /DEF=B subtilis lys gene for diaminopimelate decarboxylase (EC 4.1.1.20).
# AFFX-r2-Bs-lys-M_at      B. subtilis /GEN=lys /DB_XREF=gb:X17013.1 /NOTE=SIF corresponding to nucleotides 673-1002 of gb:X17013.1, not 100% identical /DEF=B subtilis lys gene for diaminopimelate decarboxylase (EC 4.1.1.20).
# AFFX-r2-Bs-phe-3_at      B. subtilis /GEN=pheB /DB_XREF=gb:M24537.1 /NOTE=SIF corresponding to nucleotides 2897-3200 of gb:M24537.1, not 100% identical /DEF=Bacillus subtillis sporulation protein (spoOB), GTP-binding protein (obg), phenylalanine biosynthesis associated protein (pheB), and monofunctional prephenate dehydratase (pheA) genes, complete cds.
# AFFX-r2-Bs-phe-5_at      B. subtilis /GEN=pheA /DB_XREF=gb:M24537.1 /NOTE=SIF corresponding to nucleotides 2116-2382 of gb:M24537.1 /DEF=Bacillus subtillis sporulation protein (spoOB), GTP-binding protein (obg), phenylalanine biosynthesis associated protein (pheB), and monofunctional prephenate dehydratase (pheA) genes, complete cds.
# AFFX-r2-Bs-phe-M_at      B. subtilis /GEN=pheA /DB_XREF=gb:M24537.1 /NOTE=SIF corresponding to nucleotides 2484-2875 of gb:M24537.1 /DEF=Bacillus subtillis sporulation protein (spoOB), GTP-binding protein (obg), phenylalanine biosynthesis associated protein (pheB), and monofunctional prephenate dehydratase (pheA) genes, complete cds.
# AFFX-r2-Bs-thr-3_s_at    B. subtilis /GEN=thrB /DB_XREF=gb:X04603.1 /NOTE=SIF corresponding to nucleotides 1735-2143 of gb:X04603.1 /DEF=B. subtilis thrB and thrC genes for homoserine kinase and threonine synthase.
# AFFX-r2-Bs-thr-5_s_at    B. subtilis /GEN=thrC /DB_XREF=gb:X04603.1 /NOTE=SIF corresponding to nucleotides 290-888 of gb:X04603.1 /DEF=B. subtilis thrB and thrC genes for homoserine kinase and threonine synthase.
# AFFX-r2-Bs-thr-M_s_at    B. subtilis /GEN=thrC, thrB /DB_XREF=gb:X04603.1 /NOTE=SIF corresponding to nucleotides 1045-1556 of gb:X04603.1 /DEF=B. subtilis thrB and thrC genes for homoserine kinase and threonine synthase.
# AFFX-r2-Ec-bioB-3_at     E. coli /GEN=bioB /DB_XREF=gb:J04423.1 /NOTE=SIF corresponding to nucleotides 2772-3004 of gb:J04423.1 /DEF=E.coli 7,8-diamino-pelargonic acid (bioA), biotin synthetase (bioB), 7-keto-8-amino-pelargonic acid synthetase (bioF), bioC protein, and dethiobiotin synthetase (bioD), complete cds.
# AFFX-r2-Ec-bioB-5_at     E. coli /GEN=bioB /DB_XREF=gb:J04423.1 /NOTE=SIF corresponding to nucleotides 2071-2304 of gb:J04423.1 /DEF=E.coli 7,8-diamino-pelargonic acid (bioA), biotin synthetase (bioB), 7-keto-8-amino-pelargonic acid synthetase (bioF), bioC protein, and dethiobiotin synthetase (bioD), complete cds.
# AFFX-r2-Ec-bioB-M_at     E. coli /GEN=bioB /DB_XREF=gb:J04423.1 /NOTE=SIF corresponding to nucleotides 2393-2682 of gb:J04423.1 /DEF=E.coli 7,8-diamino-pelargonic acid (bioA), biotin synthetase (bioB), 7-keto-8-amino-pelargonic acid synthetase (bioF), bioC protein, and dethiobiotin synthetase (bioD), complete cds.
# AFFX-r2-Ec-bioC-3_at     E. coli /GEN=bioC /DB_XREF=gb:J04423.1 /NOTE=SIF corresponding to nucleotides 4608-4883 of gb:J04423.1 /DEF=E.coli 7,8-diamino-pelargonic acid (bioA), biotin synthetase (bioB), 7-keto-8-amino-pelargonic acid synthetase (bioF), bioC protein, and dethiobiotin synthetase (bioD), complete cds.
# AFFX-r2-Ec-bioC-5_at     E. coli /GEN=bioC /DB_XREF=gb:J04423.1 /NOTE=SIF corresponding to nucleotides 4257-4573 of gb:J04423.1 /DEF=E.coli 7,8-diamino-pelargonic acid (bioA), biotin synthetase (bioB), 7-keto-8-amino-pelargonic acid synthetase (bioF), bioC protein, and dethiobiotin synthetase (bioD), complete cds.
# AFFX-r2-Ec-bioD-3_at     E. coli /GEN=bioD /DB_XREF=gb:J04423.1 /NOTE=SIF corresponding to nucleotides 5312-5559 of gb:J04423.1, not 100% identical /DEF=E.coli 7,8-diamino-pelargonic acid (bioA), biotin synthetase (bioB), 7-keto-8-amino-pelargonic acid synthetase (bioF), bioC protein, and dethiobiotin synthetase (bioD), complete cds.
# AFFX-r2-Ec-bioD-5_at     E. coli /GEN=bioD /DB_XREF=gb:J04423.1 /NOTE=SIF corresponding to nucleotides 5024-5244 of gb:J04423.1 /DEF=E.coli 7,8-diamino-pelargonic acid (bioA), biotin synthetase (bioB), 7-keto-8-amino-pelargonic acid synthetase (bioF), bioC protein, and dethiobiotin synthetase (bioD), complete cds.
# AFFX-r2-Hs18SrRNA-3_s_at M10098.1 Human 18S rRNA sequence, length 1969 bases, 3 prime target bases 1293-1938
# AFFX-r2-Hs18SrRNA-5_at   M10098.1 Human 18S rRNA sequence, length 1969 bases, 5 prime target bases 1-646
# AFFX-r2-Hs18SrRNA-M_x_at M10098.1 Human 18S rRNA sequence, length 1969 bases, middle target bases 647-1292
# AFFX-r2-Hs28SrRNA-3_at   M11167.1 Human 28S rRNA sequence, length 5025 bases, middle target bases 1666-3330
# AFFX-r2-Hs28SrRNA-5_at   M11167.1 Human 28S rRNA sequence, length 5025 bases, 5 prime target bases 1-1665
# AFFX-r2-Hs28SrRNA-M_at   M11167.1 Human 28S rRNA sequence, length 5025 bases, 3 prime target bases 3331-4995
# AFFX-r2-P1-cre-3_at      Bacteriophage P1 /GEN=cre /DB_XREF=gb:X03453.1 /NOTE=SIF corresponding to nucleotides 1032-1270 of gb:X03453.1 /DEF=Bacteriophage P1 cre gene for recombinase protein.
# AFFX-r2-P1-cre-5_at      Bacteriophage P1 /GEN=cre /DB_XREF=gb:X03453.1 /NOTE=SIF corresponding to nucleotides 581-1001 of gb:X03453.1 /DEF=Bacteriophage P1 cre gene for recombinase protein.
# AFFX-ThrX-3_at           B. subtilis /GEN=thrB /DB_XREF=gb:X04603.1 /NOTE=SIF corresponding to nucleotides 1689-2151 of gb:X04603.1 /DEF=B. subtilis thrB and thrC genes for homoserine kinase and threonine synthase (EC 2.7.1.39 and EC 4.2.99.2, respectively).
# AFFX-ThrX-5_at           B. subtilis /GEN=thrC /DB_XREF=gb:X04603.1 /NOTE=SIF corresponding to nucleotides 288-932 of gb:X04603.1 /DEF=B. subtilis thrB and thrC genes for homoserine kinase and threonine synthase (EC 2.7.1.39 and EC 4.2.99.2, respectively).
# AFFX-ThrX-M_at           B. subtilis /GEN=thrC, thrB /DB_XREF=gb:X04603.1 /NOTE=SIF corresponding to nucleotides 995-1562 of gb:X04603.1, not 100% identical /DEF=B. subtilis thrB and thrC genes for homoserine kinase and threonine synthase (EC 2.7.1.39 and EC 4.2.99.2, respectively).
# AFFX-TrpnX-3_at          B. subtilis /GEN=trpC, trpF /DB_XREF=gb:K01391.1 /NOTE=SIF corresponding to nucleotides 3790-4368 of gb:K01391.1, not 100% identical /DEF=B.subtilis tryptophan (trp) operon, complete cds.
# AFFX-TrpnX-5_at          B. subtilis /GEN=trpE, trpD /DB_XREF=gb:K01391.1 /NOTE=SIF corresponding to nucleotides 1953-2483 of gb:K01391.1, not 100% identical /DEF=B.subtilis tryptophan (trp) operon, complete cds.
# AFFX-TrpnX-M_at          B. subtilis /GEN=trpD, trpC /DB_XREF=gb:K01391.1 /NOTE=SIF corresponding to nucleotides 2880-3359 of gb:K01391.1, not 100% identical /DEF=B.subtilis tryptophan (trp) operon, complete cds.
#                          Representative Public ID
# 1007_s_at                U48705
# 1053_at                  M87338
# 117_at                   X51757
# 121_at                   X69699
# 1255_g_at                L36861
# 1294_at                  L13852
# 1316_at                  X55005
# 1320_at                  X79510
# 1405_i_at                M21121
# 1431_at                  J02843
# 1438_at                  X75208
# 1487_at                  L38487
# 1494_f_at                M33318
# 1598_g_at                L13720
# 160020_at                Z48481
# 1729_at                  L41690
# 1773_at                  L00635
# 177_at                   U38545
# 179_at                   U38980
# 1861_at                  U66879
# 200000_s_at              NM_006445
# 200001_at                NM_001749
# 200002_at                NM_007209
# 200003_s_at              NM_000991
# 200004_at                NM_001418
# 200005_at                NM_003753
# 200006_at                NM_007262
# 200007_at                NM_003134
# 200008_s_at              D13988
# 200009_at                NM_001494
# ⋮                        ⋮
# AFFX-r2-Bs-lys-3_at      AFFX-r2-Bs-lys-3
# AFFX-r2-Bs-lys-5_at      AFFX-r2-Bs-lys-5
# AFFX-r2-Bs-lys-M_at      AFFX-r2-Bs-lys-M
# AFFX-r2-Bs-phe-3_at      AFFX-r2-Bs-phe-3
# AFFX-r2-Bs-phe-5_at      AFFX-r2-Bs-phe-5
# AFFX-r2-Bs-phe-M_at      AFFX-r2-Bs-phe-M
# AFFX-r2-Bs-thr-3_s_at    AFFX-r2-Bs-thr-3
# AFFX-r2-Bs-thr-5_s_at    AFFX-r2-Bs-thr-5
# AFFX-r2-Bs-thr-M_s_at    AFFX-r2-Bs-thr-M
# AFFX-r2-Ec-bioB-3_at     AFFX-r2-Ec-bioB-3
# AFFX-r2-Ec-bioB-5_at     AFFX-r2-Ec-bioB-5
# AFFX-r2-Ec-bioB-M_at     AFFX-r2-Ec-bioB-M
# AFFX-r2-Ec-bioC-3_at     AFFX-r2-Ec-bioC-3
# AFFX-r2-Ec-bioC-5_at     AFFX-r2-Ec-bioC-5
# AFFX-r2-Ec-bioD-3_at     AFFX-r2-Ec-bioD-3
# AFFX-r2-Ec-bioD-5_at     AFFX-r2-Ec-bioD-5
# AFFX-r2-Hs18SrRNA-3_s_at AFFX-r2-Hs18SrRNA-3
# AFFX-r2-Hs18SrRNA-5_at   AFFX-r2-Hs18SrRNA-5
# AFFX-r2-Hs18SrRNA-M_x_at AFFX-r2-Hs18SrRNA-M
# AFFX-r2-Hs28SrRNA-3_at   AFFX-r2-Hs28SrRNA-3
# AFFX-r2-Hs28SrRNA-5_at   AFFX-r2-Hs28SrRNA-5
# AFFX-r2-Hs28SrRNA-M_at   AFFX-r2-Hs28SrRNA-M
# AFFX-r2-P1-cre-3_at      AFFX-r2-P1-cre-3
# AFFX-r2-P1-cre-5_at      AFFX-r2-P1-cre-5
# AFFX-ThrX-3_at           AFFX-ThrX-3
# AFFX-ThrX-5_at           AFFX-ThrX-5
# AFFX-ThrX-M_at           AFFX-ThrX-M
# AFFX-TrpnX-3_at          AFFX-TrpnX-3
# AFFX-TrpnX-5_at          AFFX-TrpnX-5
# AFFX-TrpnX-M_at          AFFX-TrpnX-M
#                          Gene Title
# 1007_s_at                discoidin domain receptor tyrosine kinase 1 /// microRNA 4640
# 1053_at                  replication factor C (activator 1) 2, 40kDa
# 117_at                   heat shock 70kDa protein 6 (HSP70B')
# 121_at                   paired box 8
# 1255_g_at                guanylate cyclase activator 1A (retina)
# 1294_at                  microRNA 5193 /// ubiquitin-like modifier activating enzyme 7
# 1316_at                  thyroid hormone receptor, alpha
# 1320_at                  protein tyrosine phosphatase, non-receptor type 21
# 1405_i_at                chemokine (C-C motif) ligand 5
# 1431_at                  cytochrome P450, family 2, subfamily E, polypeptide 1
# 1438_at                  EPH receptor B3
# 1487_at                  estrogen-related receptor alpha
# 1494_f_at                cytochrome P450, family 2, subfamily A, polypeptide 6
# 1598_g_at                growth arrest-specific 6
# 160020_at                matrix metallopeptidase 14 (membrane-inserted)
# 1729_at                  TNFRSF1A-associated via death domain
# 1773_at                  CHURC1-FNTB readthrough /// farnesyltransferase, CAAX box, beta
# 177_at                   phospholipase D1, phosphatidylcholine-specific
# 179_at                   DTX2P1-UPK3BP1-PMS2P11 readthrough transcribed pseudogene
# 1861_at                  BCL2-associated agonist of cell death
# 200000_s_at              pre-mRNA processing factor 8
# 200001_at                calpain, small subunit 1
# 200002_at                ribosomal protein L35
# 200003_s_at              microRNA 6805 /// ribosomal protein L28
# 200004_at                eukaryotic translation initiation factor 4 gamma, 2
# 200005_at                eukaryotic translation initiation factor 3, subunit D
# 200006_at                parkinson protein 7
# 200007_at                signal recognition particle 14kDa (homologous Alu RNA binding protein)
# 200008_s_at              GDP dissociation inhibitor 2
# 200009_at                GDP dissociation inhibitor 2
# ⋮                        ⋮
# AFFX-r2-Bs-lys-3_at
# AFFX-r2-Bs-lys-5_at
# AFFX-r2-Bs-lys-M_at
# AFFX-r2-Bs-phe-3_at
# AFFX-r2-Bs-phe-5_at
# AFFX-r2-Bs-phe-M_at
# AFFX-r2-Bs-thr-3_s_at
# AFFX-r2-Bs-thr-5_s_at
# AFFX-r2-Bs-thr-M_s_at
# AFFX-r2-Ec-bioB-3_at
# AFFX-r2-Ec-bioB-5_at
# AFFX-r2-Ec-bioB-M_at
# AFFX-r2-Ec-bioC-3_at
# AFFX-r2-Ec-bioC-5_at
# AFFX-r2-Ec-bioD-3_at
# AFFX-r2-Ec-bioD-5_at
# AFFX-r2-Hs18SrRNA-3_s_at
# AFFX-r2-Hs18SrRNA-5_at
# AFFX-r2-Hs18SrRNA-M_x_at
# AFFX-r2-Hs28SrRNA-3_at
# AFFX-r2-Hs28SrRNA-5_at
# AFFX-r2-Hs28SrRNA-M_at
# AFFX-r2-P1-cre-3_at
# AFFX-r2-P1-cre-5_at
# AFFX-ThrX-3_at
# AFFX-ThrX-5_at
# AFFX-ThrX-M_at
# AFFX-TrpnX-3_at
# AFFX-TrpnX-5_at
# AFFX-TrpnX-M_at
#                          Gene Symbol            ENTREZ_GENE_ID
# 1007_s_at                DDR1 /// MIR4640       780 /// 100616237
# 1053_at                  RFC2                   5982
# 117_at                   HSPA6                  3310
# 121_at                   PAX8                   7849
# 1255_g_at                GUCA1A                 2978
# 1294_at                  MIR5193 /// UBA7       7318 /// 100847079
# 1316_at                  THRA                   7067
# 1320_at                  PTPN21                 11099
# 1405_i_at                CCL5                   6352
# 1431_at                  CYP2E1                 1571
# 1438_at                  EPHB3                  2049
# 1487_at                  ESRRA                  2101
# 1494_f_at                CYP2A6                 1548
# ...
# AFFX-r2-P1-cre-5_at
# AFFX-ThrX-3_at
# AFFX-ThrX-5_at
# AFFX-ThrX-M_at
# AFFX-TrpnX-3_at
# AFFX-TrpnX-5_at
# AFFX-TrpnX-M_at

# %% [markdown]
# Dados de expressão:

# %%
exprs(gse) ## print the expression data
# Out:
#                          GSM517355 GSM517356 GSM517357 GSM517358 GSM517359
# 1007_s_at                11.007402 11.007287 11.043006 10.996446 10.655054
# 1053_at                   7.173564  7.027160  7.022269  6.965315  7.018888
# 117_at                    7.031011  7.047853  7.013883  7.046787  6.952204
# 121_at                   10.395251 10.478962 10.569338 10.519554 10.393992
# 1255_g_at                 4.569596  4.576886  4.674495  4.695978  4.567270
# 1294_at                   9.406246  9.145071  9.065041  9.056060  9.004434
# 1316_at                   5.973047  5.955183  6.069703  5.972298  5.860130
# 1320_at                   6.087714  6.006613  6.120106  6.102750  5.958276
# AFFX-r2-Bs-phe-3_at       4.822662  4.733314  4.566053
# AFFX-r2-Bs-phe-5_at       4.013043  3.902504  3.838080
# AFFX-r2-Bs-phe-M_at       4.261662  4.360419  4.338478
# AFFX-r2-Bs-thr-3_s_at     5.446215  5.494101  5.406917
# AFFX-r2-Bs-thr-5_s_at     5.280583  5.293849  5.510370
# AFFX-r2-Bs-thr-M_s_at     4.536688  4.620012  4.485042
# AFFX-r2-Ec-bioB-3_at      8.072651  8.063050  8.047453
# AFFX-r2-Ec-bioB-5_at      8.192007  7.943296  8.198909
# AFFX-r2-Ec-bioB-M_at      8.855587  8.468292  8.685745
# AFFX-r2-Ec-bioC-3_at      9.737678  9.488915  9.630828
# AFFX-r2-Ec-bioC-5_at      9.525603  9.310402  9.415370
# AFFX-r2-Ec-bioD-3_at     11.671992 11.456076 11.435568
# AFFX-r2-Ec-bioD-5_at     11.376044 11.194668 11.238227
# AFFX-r2-Hs18SrRNA-3_s_at 12.282122 12.115096 12.054953
# AFFX-r2-Hs18SrRNA-5_at   13.046025 13.287898 13.145824
# AFFX-r2-Hs18SrRNA-M_x_at 13.251798 13.477575 13.287111
# AFFX-r2-Hs28SrRNA-3_at   11.962880 11.578987 12.156180
# AFFX-r2-Hs28SrRNA-5_at    8.208675  8.464256  9.056686
# AFFX-r2-Hs28SrRNA-M_at   10.666441 10.533336 11.166699
# AFFX-r2-P1-cre-3_at      13.823963 13.668965 13.673392
# AFFX-r2-P1-cre-5_at      13.461008 13.407099 13.638876
# AFFX-ThrX-3_at            5.492836  5.345382  5.454981
# AFFX-ThrX-5_at            4.947446  4.762043  4.887915
# AFFX-ThrX-M_at            4.212101  4.093239  4.198891
# AFFX-TrpnX-3_at           3.971855  3.961965  4.005788
# AFFX-TrpnX-5_at           4.530390  4.424787  4.419458
# AFFX-TrpnX-M_at           4.373748  4.296080  4.206222

# %% [markdown]
# ## Verificando a normalização e as escalas usadas
# Para visualização e análise estatística, vamos inspecionar os dados para descobrir em que escala os dados são apresentados. Os métodos que usaremos assumem que os dados estão em uma escala log2, tipicamente na faixa de 0 a 16.
#
# A função `exprs` pode recuperar os valores de expressão como um quadro de dados; com uma coluna por amostra e uma linha por gene.
#
# A função `summary` pode então ser usada para imprimir as distribuições.

# %%
## exprs get the expression levels as a data frame and get the distribution
summary(exprs(gse))
# Out:
#    GSM517355        GSM517356        GSM517357        GSM517358
#  Min.   : 3.597   Min.   : 3.616   Min.   : 3.630   Min.   : 3.660
#  1st Qu.: 5.870   1st Qu.: 5.888   1st Qu.: 5.952   1st Qu.: 5.914
#  Median : 7.252   Median : 7.261   Median : 7.271   Median : 7.258
#  Mean   : 7.509   Mean   : 7.502   Mean   : 7.529   Mean   : 7.507
#  3rd Qu.: 8.996   3rd Qu.: 8.946   3rd Qu.: 8.930   3rd Qu.: 8.922
#  Max.   :14.394   Max.   :14.425   Max.   :14.390   Max.   :14.436
#    GSM517359        GSM517360        GSM517361        GSM517362
#  Min.   : 3.632   Min.   : 3.639   Min.   : 3.556   Min.   : 3.526
#  1st Qu.: 5.842   1st Qu.: 5.916   1st Qu.: 5.885   1st Qu.: 5.833
#  Median : 7.255   Median : 7.274   Median : 7.266   Median : 7.249
#  Mean   : 7.495   Mean   : 7.503   Mean   : 7.503   Mean   : 7.496
#  3rd Qu.: 8.971   3rd Qu.: 8.911   3rd Qu.: 8.950   3rd Qu.: 8.984
#  Max.   :14.435   Max.   :14.397   Max.   :14.395   Max.   :14.412
#    GSM517363        GSM517364        GSM517365        GSM517366
#  Min.   : 3.609   Min.   : 3.634   Min.   : 3.638   Min.   : 3.660
#  1st Qu.: 5.820   1st Qu.: 5.892   1st Qu.: 5.874   1st Qu.: 5.874
#  Median : 7.224   Median : 7.258   Median : 7.259   Median : 7.234
#  Mean   : 7.489   Mean   : 7.497   Mean   : 7.506   Mean   : 7.499
#  3rd Qu.: 8.973   3rd Qu.: 8.914   3rd Qu.: 8.955   3rd Qu.: 8.938
#  Max.   :14.503   Max.   :14.484   Max.   :14.377   Max.   :14.426
#    GSM517367        GSM517368        GSM517369        GSM517370
#  Min.   : 3.609   Min.   : 3.669   Min.   : 3.672   Min.   : 3.687
#  1st Qu.: 5.810   1st Qu.: 5.879   1st Qu.: 6.008   1st Qu.: 6.010
#  Median : 7.220   Median : 7.240   Median : 7.300   Median : 7.301
#  Mean   : 7.489   Mean   : 7.502   Mean   : 7.516   Mean   : 7.509
#  3rd Qu.: 8.988   3rd Qu.: 8.938   3rd Qu.: 8.840   3rd Qu.: 8.810
#  Max.   :14.348   Max.   :14.376   Max.   :14.332   Max.   :14.532
#    GSM517371        GSM517372
#  Min.   : 3.628   Min.   : 3.613
#  1st Qu.: 5.920   1st Qu.: 5.966
#  Median : 7.255   Median : 7.277
#  Mean   : 7.498   Mean   : 7.502
#  3rd Qu.: 8.890   3rd Qu.: 8.846
#  Max.   :14.533   Max.   :14.416

# %% [markdown]
# Um boxplot também pode ser gerado para ver se os dados foram normalizados. Se sim, as distribuições de cada amostra devem ser muito semelhantes.

# %%
boxplot(exprs(gse),outline=FALSE)
# Out:
# plot without title

# %% [markdown]
# Verifique se os valores vão muito além de 16. Se sim, precisaremos realizar uma transformação Log2.
#
# **Só execute a célula abaixo se for o caso. Para o *dataset* exemplo ela não é necessária.**

# %%
# exprs(gse) <- log2(exprs(gse))

# %% [markdown]
# ### Inspecionando as variáveis clínicas
#
# Os dados enviados para o GEO contêm rótulos de amostras atribuídos pelos grupos de pesquisa e algumas informações sobre o protocolo de processamento. Todos esses dados podem ser extraídos pela função `pData`.
#
# Para seus próprios dados, você terá que decidir quais colunas serão úteis na análise. Isso incluirá a coluna que fornece as comparações de interesse e quaisquer fatores confundidores potenciais. Neste conjunto de dados específico, parece que são `source_name_ch1` e `disease state:ch1`.
#
# Podemos usar a função select do `dplyr` para exibir apenas essas colunas de interesse. Nesta fase, também será útil renomear as colunas para algo mais conveniente usando a função `rename`. No caso exemplo, utilizaremos `Sample` e `State`.

# %%
library(dplyr)
sampleInfo <- pData(gse)
sampleInfo
# Out:
# Attaching package: ‘dplyr’
#
#
# The following object is masked from ‘package:Biobase’:
#
#     combine
#
#
# The following objects are masked from ‘package:BiocGenerics’:
#
#     combine, intersect, setdiff, union
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM517nnn/GSM517372/suppl/GSM517372_GLOM-HGU133A-TN3b.CEL.gz
#           data_row_count disease state:ch1 tissue:ch1
# GSM517355 22283          nephrosclerosis   glomeruli of human kidney
# GSM517356 22283          nephrosclerosis   glomeruli of human kidney
# GSM517357 22283          nephrosclerosis   glomeruli of human kidney
# GSM517358 22283          nephrosclerosis   glomeruli of human kidney
# GSM517359 22283          nephrosclerosis   glomeruli of human kidney
# GSM517360 22283          nephrosclerosis   glomeruli of human kidney
# GSM517361 22283          nephrosclerosis   glomeruli of human kidney
# GSM517362 22283          nephrosclerosis   glomeruli of human kidney
# GSM517363 22283          nephrosclerosis   glomeruli of human kidney
# GSM517364 22283          nephrosclerosis   glomeruli of human kidney
# GSM517365 22283          nephrosclerosis   glomeruli of human kidney
# GSM517366 22283          nephrosclerosis   glomeruli of human kidney
# GSM517367 22283          nephrosclerosis   glomeruli of human kidney
# GSM517368 22283          nephrosclerosis   glomeruli of human kidney
# GSM517369 22283          control           glomeruli of human kidney
# GSM517370 22283          control           glomeruli of human kidney
# GSM517371 22283          control           glomeruli of human kidney
# GSM517372 22283          control           glomeruli of human kidney

# %%
# source_name_ch1 and disease state:ch1 seem to contain factors we might need for the analysis. Let's pick just those columns
sampleInfo <- select(sampleInfo, "source_name_ch1","disease state:ch1")
sampleInfo
# Out:
#           source_name_ch1                                    disease state:ch1
# GSM517355 kidney biopsy from patient with NSC                nephrosclerosis
# GSM517356 kidney biopsy from patient with NSC                nephrosclerosis
# GSM517357 kidney biopsy from patient with NSC                nephrosclerosis
# GSM517358 kidney biopsy from patient with NSC                nephrosclerosis
# GSM517359 kidney biopsy from patient with NSC                nephrosclerosis
# GSM517360 kidney biopsy from patient with NSC                nephrosclerosis
# GSM517361 kidney biopsy from patient with NSC                nephrosclerosis
# GSM517362 kidney biopsy from patient with NSC                nephrosclerosis
# GSM517363 kidney biopsy from patient with NSC                nephrosclerosis
# GSM517364 kidney biopsy from patient with NSC                nephrosclerosis
# GSM517365 kidney biopsy from patient with NSC                nephrosclerosis
# GSM517366 kidney biopsy from patient with NSC                nephrosclerosis
# GSM517367 kidney biopsy from patient with NSC                nephrosclerosis
# GSM517368 kidney biopsy from patient after Tumor Nephrectomy nephrosclerosis
# GSM517369 kidney biopsy from patient after Tumor Nephrectomy control
# GSM517370 kidney biopsy from patient after Tumor Nephrectomy control
# GSM517371 kidney biopsy from patient after Tumor Nephrectomy control
# GSM517372 kidney biopsy from patient after Tumor Nephrectomy control

# %%
## Optionally, rename to more convenient column names
sampleInfo <- rename(sampleInfo, "Sample"="source_name_ch1", "State"="disease state:ch1")

# %% [markdown]
# A informação da amostra então ficará assim:

# %%
sampleInfo
# Out:
#           Sample                                             State
# GSM517355 kidney biopsy from patient with NSC                nephrosclerosis
# GSM517356 kidney biopsy from patient with NSC                nephrosclerosis
# GSM517357 kidney biopsy from patient with NSC                nephrosclerosis
# GSM517358 kidney biopsy from patient with NSC                nephrosclerosis
# GSM517359 kidney biopsy from patient with NSC                nephrosclerosis
# GSM517360 kidney biopsy from patient with NSC                nephrosclerosis
# GSM517361 kidney biopsy from patient with NSC                nephrosclerosis
# GSM517362 kidney biopsy from patient with NSC                nephrosclerosis
# GSM517363 kidney biopsy from patient with NSC                nephrosclerosis
# GSM517364 kidney biopsy from patient with NSC                nephrosclerosis
# GSM517365 kidney biopsy from patient with NSC                nephrosclerosis
# GSM517366 kidney biopsy from patient with NSC                nephrosclerosis
# GSM517367 kidney biopsy from patient with NSC                nephrosclerosis
# GSM517368 kidney biopsy from patient after Tumor Nephrectomy nephrosclerosis
# GSM517369 kidney biopsy from patient after Tumor Nephrectomy control
# GSM517370 kidney biopsy from patient after Tumor Nephrectomy control
# GSM517371 kidney biopsy from patient after Tumor Nephrectomy control
# GSM517372 kidney biopsy from patient after Tumor Nephrectomy control

# %% [markdown]
# A classificação das amostras na coluna `Sample` é dada por termos muito grandes. Vamos resumir, usando a biblioteca `dplyr`, nas seguintes condições:
# - Renomear "kidney biopsy from patient with NSC" para apenas "NSC"
# - Renomear "kidney biopsy from patient after Tumor Nephrectomy" para apenas "aTN".
# Assim os dados ficam mais fáceis de serem analisados, tanto para a PCA, como para os *heatmaps*.

# %%
sampleInfo <- sampleInfo %>%
    mutate(Sample = case_when(
        Sample == "kidney biopsy from patient with NSC" ~ "NSC",
        Sample == "kidney biopsy from patient after Tumor Nephrectomy" ~ "aTN",
        TRUE ~ Sample
    ))
sampleInfo
# Out:
#           Sample State
# GSM517355 NSC    nephrosclerosis
# GSM517356 NSC    nephrosclerosis
# GSM517357 NSC    nephrosclerosis
# GSM517358 NSC    nephrosclerosis
# GSM517359 NSC    nephrosclerosis
# GSM517360 NSC    nephrosclerosis
# GSM517361 NSC    nephrosclerosis
# GSM517362 NSC    nephrosclerosis
# GSM517363 NSC    nephrosclerosis
# GSM517364 NSC    nephrosclerosis
# GSM517365 NSC    nephrosclerosis
# GSM517366 NSC    nephrosclerosis
# GSM517367 NSC    nephrosclerosis
# GSM517368 aTN    nephrosclerosis
# GSM517369 aTN    control
# GSM517370 aTN    control
# GSM517371 aTN    control
# GSM517372 aTN    control

# %% [markdown]
# ## Clusterização das amostras e Análise de Componentes Principais (PCA)
#
# A análise não supervisionada é uma boa maneira de entender as fontes de variação nos dados. Ela também pode identificar possíveis amostras discrepantes (os chamados "*outliers*".
#
# A função `cor` pode calcular a correlação (na escala de 0 - 1) de maneira par a par entre todas as amostras. Isso pode ser visualizado em um *heatmap*. Entre as muitas opções para criar *heatmaps* em R, a biblioteca `pheatmap` é uma das mais populares. O único argumento que ela requer é uma matriz de valores numéricos (como a matriz de correlação).

# %%
library(pheatmap)
## argument use="c" stops an error if there are any missing data points

corMatrix <- cor(exprs(gse),use="c")
pheatmap(corMatrix)
# Out:
# plot without title

# %% [markdown]
# Podemos incorporar informações da amostra no gráfico para tentar entender o agrupamento. Já criamos um quadro de dados assim anteriormente (sampleInfo). No entanto, precisamos ter cuidado para que os nomes das linhas desses dados correspondam às colunas da matriz de correlação.

# %%
## Print the rownames of the sample information and check it matches the correlation matrix
rownames(sampleInfo)
# Out:
#  [1] "GSM517355" "GSM517356" "GSM517357" "GSM517358" "GSM517359" "GSM517360"
#  [7] "GSM517361" "GSM517362" "GSM517363" "GSM517364" "GSM517365" "GSM517366"
# [13] "GSM517367" "GSM517368" "GSM517369" "GSM517370" "GSM517371" "GSM517372"

# %%
colnames(corMatrix)
# Out:
#  [1] "GSM517355" "GSM517356" "GSM517357" "GSM517358" "GSM517359" "GSM517360"
#  [7] "GSM517361" "GSM517362" "GSM517363" "GSM517364" "GSM517365" "GSM517366"
# [13] "GSM517367" "GSM517368" "GSM517369" "GSM517370" "GSM517371" "GSM517372"

# %% [markdown]
# Se não estiverem iguais, execute o código abaixo. Se estiverem iguais, pode passar para a próxima etapa.

# %%
## If not, force the rownames to match the columns

# rownames(sampleInfo) <- colnames(corMatrix)

# %% [markdown]
# Se estiverem iguais, apenas confirme, obtendo o heatmap:

# %%
pheatmap(corMatrix,
         annotation_col=sampleInfo)
# Out:
# plot without title

# %% [markdown]
# Aqui vemos que a principal separação é devido a Control vs Nephrosclerosis; como esperamos, com uma pequena diferença.
#
# Uma abordagem complementar é usar a Análise de Componentes Principais (PCA). Há uma boa explicação neste [vídeo do YouTube](https://www.youtube.com/watch?v=0Jp4gsfOLMs).
#
# É importante transpor a matriz de expressão, caso contrário, o R tentará calcular a PCA nos genes (em vez de amostras) e poderá ficar sem memória.
#
# Como a PCA é um método não supervisionado, os grupos de amostras conhecidos não são levados em conta. No entanto, podemos adicionar rótulos quando plotamos os resultados. O pacote `ggplot2` é particularmente conveniente para isso. O pacote `ggrepel` pode ser usado para posicionar os rótulos de texto de maneira mais inteligente para que possam ser lidos.

# %%
library(ggplot2)
library(ggrepel)

# %% [markdown]
# E agora executaremos a PCA:

# %%
## MAKE SURE TO TRANSPOSE THE EXPRESSION MATRIX

pca <- prcomp(t(exprs(gse)))

## Join the PCs to the sample information
cbind(sampleInfo, pca$x) %>%
    ggplot(aes(x = PC1, y=PC2, col=State,label=paste("", Sample))) + geom_point() + geom_text_repel()
# Out:
# plot without title

# %% [markdown]
# ### O que acontece se identificarmos um efeito de lote (*batch effect*)?
#
# Nada nesta fase. Desde que o desenho experimental seja sensato (ou seja, representantes de todos os grupos de amostras estão presentes em cada lote), podemos corrigir o lote quando executamos a análise de expressão diferencial.

# %% [markdown]
# ### O que acontece se detectarmos outliers?
#
# Se suspeitarmos que algumas amostras são outliers, podemos removê-las para análise posterior.
#
# >***Atenção***
# >
# >Não precisa executar o código abaixo se você não tiver detectado *outliers*.

# %%
### CODE ONLY FOR DEMONSTRATION ONLY

### lets' say are outliers are samples 1,2 and 3
## replace 1,2,3 with the outliers in your dataset
#outlier_samples <- c(1,2,3)

#gse <- gse[,-outlier_samples]

# %% [markdown]
# ## Exportando os dados
#
# Podemos exportar os dados de expressão para um `csv` para inspeção no Excel usando a função `write_csv` do `readr`. Os próprios valores de expressão provavelmente não serão muito úteis, pois serão nomeados de acordo com o ID do fabricante em vez do nome do gene (por exemplo). Podemos criar uma matriz juntando a matriz de expressão com a anotação de recursos.

# %%
library(readr)
full_output <- cbind(fData(gse),exprs(gse))
write_csv(full_output, file="gse_full_output.csv")

# %% [markdown]
# A anotação do GEO pode conter muitas colunas que não nos interessam. Para manter os dados mais organizados, podemos usar a função `select` para imprimir apenas colunas específicas na saída.

# %%
features <- fData(gse)
View(features)
# Out:
#                          ID                       GB_ACC    SPOT_ID
# 1007_s_at                1007_s_at                U48705
# 1053_at                  1053_at                  M87338
# 117_at                   117_at                   X51757
# 121_at                   121_at                   X69699
# 1255_g_at                1255_g_at                L36861
# 1294_at                  1294_at                  L13852
# 1316_at                  1316_at                  X55005
# 1320_at                  1320_at                  X79510
# 1405_i_at                1405_i_at                M21121
# 1431_at                  1431_at                  J02843
# 1438_at                  1438_at                  X75208
# 1487_at                  1487_at                  L38487
# 1494_f_at                1494_f_at                M33318
# 1598_g_at                1598_g_at                L13720
# 160020_at                160020_at                Z48481
# 1729_at                  1729_at                  L41690
# 1773_at                  1773_at                  L00635
# 177_at                   177_at                   U38545
# 179_at                   179_at                   U38980
# 1861_at                  1861_at                  U66879
# 200000_s_at              200000_s_at              NM_006445
# 200001_at                200001_at                NM_001749
# 200002_at                200002_at                NM_007209
# 200003_s_at              200003_s_at              NM_000991
# 200004_at                200004_at                NM_001418
# 200005_at                200005_at                NM_003753
# 200006_at                200006_at                NM_007262
# 200007_at                200007_at                NM_003134
# 200008_s_at              200008_s_at              D13988
# 200009_at                200009_at                NM_001494
# ⋮                        ⋮                        ⋮         ⋮
# AFFX-r2-Bs-lys-3_at      AFFX-r2-Bs-lys-3_at                --Control
# AFFX-r2-Bs-lys-5_at      AFFX-r2-Bs-lys-5_at                --Control
# AFFX-r2-Bs-lys-M_at      AFFX-r2-Bs-lys-M_at                --Control
# AFFX-r2-Bs-phe-3_at      AFFX-r2-Bs-phe-3_at                --Control
# AFFX-r2-Bs-phe-5_at      AFFX-r2-Bs-phe-5_at                --Control
# AFFX-r2-Bs-phe-M_at      AFFX-r2-Bs-phe-M_at                --Control
# AFFX-r2-Bs-thr-3_s_at    AFFX-r2-Bs-thr-3_s_at              --Control
# AFFX-r2-Bs-thr-5_s_at    AFFX-r2-Bs-thr-5_s_at              --Control
# AFFX-r2-Bs-thr-M_s_at    AFFX-r2-Bs-thr-M_s_at              --Control
# AFFX-r2-Ec-bioB-3_at     AFFX-r2-Ec-bioB-3_at               --Control
# AFFX-r2-Ec-bioB-5_at     AFFX-r2-Ec-bioB-5_at               --Control
# AFFX-r2-Ec-bioB-M_at     AFFX-r2-Ec-bioB-M_at               --Control
# AFFX-r2-Ec-bioC-3_at     AFFX-r2-Ec-bioC-3_at               --Control
# AFFX-r2-Ec-bioC-5_at     AFFX-r2-Ec-bioC-5_at               --Control
# AFFX-r2-Ec-bioD-3_at     AFFX-r2-Ec-bioD-3_at               --Control
# AFFX-r2-Ec-bioD-5_at     AFFX-r2-Ec-bioD-5_at               --Control
# AFFX-r2-Hs18SrRNA-3_s_at AFFX-r2-Hs18SrRNA-3_s_at           --Control
# AFFX-r2-Hs18SrRNA-5_at   AFFX-r2-Hs18SrRNA-5_at             --Control
# AFFX-r2-Hs18SrRNA-M_x_at AFFX-r2-Hs18SrRNA-M_x_at           --Control
# AFFX-r2-Hs28SrRNA-3_at   AFFX-r2-Hs28SrRNA-3_at             --Control
# AFFX-r2-Hs28SrRNA-5_at   AFFX-r2-Hs28SrRNA-5_at             --Control
# AFFX-r2-Hs28SrRNA-M_at   AFFX-r2-Hs28SrRNA-M_at             --Control
# AFFX-r2-P1-cre-3_at      AFFX-r2-P1-cre-3_at                --Control
# AFFX-r2-P1-cre-5_at      AFFX-r2-P1-cre-5_at                --Control
# AFFX-ThrX-3_at           AFFX-ThrX-3_at                     --Control
# AFFX-ThrX-5_at           AFFX-ThrX-5_at                     --Control
# AFFX-ThrX-M_at           AFFX-ThrX-M_at                     --Control
# AFFX-TrpnX-3_at          AFFX-TrpnX-3_at                    --Control
# AFFX-TrpnX-5_at          AFFX-TrpnX-5_at                    --Control
# AFFX-TrpnX-M_at          AFFX-TrpnX-M_at                    --Control
#                          Species Scientific Name Annotation Date
# 1007_s_at                Homo sapiens            Oct 6, 2014
# 1053_at                  Homo sapiens            Oct 6, 2014
# 117_at                   Homo sapiens            Oct 6, 2014
# 121_at                   Homo sapiens            Oct 6, 2014
# 1255_g_at                Homo sapiens            Oct 6, 2014
# 1294_at                  Homo sapiens            Oct 6, 2014
# 1316_at                  Homo sapiens            Oct 6, 2014
# 1320_at                  Homo sapiens            Oct 6, 2014
# 1405_i_at                Homo sapiens            Oct 6, 2014
# 1431_at                  Homo sapiens            Oct 6, 2014
# 1438_at                  Homo sapiens            Oct 6, 2014
# 1487_at                  Homo sapiens            Oct 6, 2014
# 1494_f_at                Homo sapiens            Oct 6, 2014
# 1598_g_at                Homo sapiens            Oct 6, 2014
# 160020_at                Homo sapiens            Oct 6, 2014
# 1729_at                  Homo sapiens            Oct 6, 2014
# 1773_at                  Homo sapiens            Oct 6, 2014
# 177_at                   Homo sapiens            Oct 6, 2014
# 179_at                   Homo sapiens            Oct 6, 2014
# 1861_at                  Homo sapiens            Oct 6, 2014
# 200000_s_at              Homo sapiens            Oct 6, 2014
# 200001_at                Homo sapiens            Oct 6, 2014
# 200002_at                Homo sapiens            Oct 6, 2014
# 200003_s_at              Homo sapiens            Oct 6, 2014
# 200004_at                Homo sapiens            Oct 6, 2014
# 200005_at                Homo sapiens            Oct 6, 2014
# 200006_at                Homo sapiens            Oct 6, 2014
# 200007_at                Homo sapiens            Oct 6, 2014
# 200008_s_at              Homo sapiens            Oct 6, 2014
# 200009_at                Homo sapiens            Oct 6, 2014
# ⋮                        ⋮                       ⋮
# AFFX-r2-Bs-lys-3_at      Homo sapiens            Oct 6, 2014
# AFFX-r2-Bs-lys-5_at      Homo sapiens            Oct 6, 2014
# AFFX-r2-Bs-lys-M_at      Homo sapiens            Oct 6, 2014
# AFFX-r2-Bs-phe-3_at      Homo sapiens            Oct 6, 2014
# AFFX-r2-Bs-phe-5_at      Homo sapiens            Oct 6, 2014
# AFFX-r2-Bs-phe-M_at      Homo sapiens            Oct 6, 2014
# AFFX-r2-Bs-thr-3_s_at    Homo sapiens            Oct 6, 2014
# AFFX-r2-Bs-thr-5_s_at    Homo sapiens            Oct 6, 2014
# AFFX-r2-Bs-thr-M_s_at    Homo sapiens            Oct 6, 2014
# AFFX-r2-Ec-bioB-3_at     Homo sapiens            Oct 6, 2014
# AFFX-r2-Ec-bioB-5_at     Homo sapiens            Oct 6, 2014
# AFFX-r2-Ec-bioB-M_at     Homo sapiens            Oct 6, 2014
# AFFX-r2-Ec-bioC-3_at     Homo sapiens            Oct 6, 2014
# AFFX-r2-Ec-bioC-5_at     Homo sapiens            Oct 6, 2014
# AFFX-r2-Ec-bioD-3_at     Homo sapiens            Oct 6, 2014
# AFFX-r2-Ec-bioD-5_at     Homo sapiens            Oct 6, 2014
# AFFX-r2-Hs18SrRNA-3_s_at Homo sapiens            Oct 6, 2014
# AFFX-r2-Hs18SrRNA-5_at   Homo sapiens            Oct 6, 2014
# AFFX-r2-Hs18SrRNA-M_x_at Homo sapiens            Oct 6, 2014
# AFFX-r2-Hs28SrRNA-3_at   Homo sapiens            Oct 6, 2014
# AFFX-r2-Hs28SrRNA-5_at   Homo sapiens            Oct 6, 2014
# AFFX-r2-Hs28SrRNA-M_at   Homo sapiens            Oct 6, 2014
# AFFX-r2-P1-cre-3_at      Homo sapiens            Oct 6, 2014
# AFFX-r2-P1-cre-5_at      Homo sapiens            Oct 6, 2014
# AFFX-ThrX-3_at           Homo sapiens            Oct 6, 2014
# AFFX-ThrX-5_at           Homo sapiens            Oct 6, 2014
# AFFX-ThrX-M_at           Homo sapiens            Oct 6, 2014
# AFFX-TrpnX-3_at          Homo sapiens            Oct 6, 2014
# AFFX-TrpnX-5_at          Homo sapiens            Oct 6, 2014
# AFFX-TrpnX-M_at          Homo sapiens            Oct 6, 2014
#                          Sequence Type      Sequence Source
# 1007_s_at                Exemplar sequence  Affymetrix Proprietary Database
# 1053_at                  Exemplar sequence  GenBank
# 117_at                   Exemplar sequence  Affymetrix Proprietary Database
# 121_at                   Exemplar sequence  GenBank
# 1255_g_at                Exemplar sequence  Affymetrix Proprietary Database
# 1294_at                  Exemplar sequence  GenBank
# 1316_at                  Exemplar sequence  Affymetrix Proprietary Database
# 1320_at                  Exemplar sequence  Affymetrix Proprietary Database
# 1405_i_at                Exemplar sequence  GenBank
# 1431_at                  Exemplar sequence  Affymetrix Proprietary Database
# 1438_at                  Exemplar sequence  Affymetrix Proprietary Database
# 1487_at                  Exemplar sequence  Affymetrix Proprietary Database
# 1494_f_at                Exemplar sequence  Affymetrix Proprietary Database
# 1598_g_at                Exemplar sequence  GenBank
# 160020_at                Consensus sequence GenBank
# 1729_at                  Exemplar sequence  GenBank
# 1773_at                  Exemplar sequence  GenBank
# 177_at                   Exemplar sequence  GenBank
# 179_at                   Exemplar sequence  GenBank
# 1861_at                  Exemplar sequence  GenBank
# 200000_s_at              Exemplar sequence  GenBank
# 200001_at                Exemplar sequence  GenBank
# 200002_at                Exemplar sequence  GenBank
# 200003_s_at              Exemplar sequence  GenBank
# 200004_at                Exemplar sequence  GenBank
# 200005_at                Exemplar sequence  GenBank
# 200006_at                Exemplar sequence  GenBank
# 200007_at                Exemplar sequence  GenBank
# 200008_s_at              Exemplar sequence  GenBank
# 200009_at                Exemplar sequence  GenBank
# ⋮                        ⋮                  ⋮
# AFFX-r2-Bs-lys-3_at      Control sequence   Affymetrix Proprietary Database
# AFFX-r2-Bs-lys-5_at      Control sequence   Affymetrix Proprietary Database
# AFFX-r2-Bs-lys-M_at      Control sequence   Affymetrix Proprietary Database
# AFFX-r2-Bs-phe-3_at      Control sequence   Affymetrix Proprietary Database
# AFFX-r2-Bs-phe-5_at      Control sequence   Affymetrix Proprietary Database
# AFFX-r2-Bs-phe-M_at      Control sequence   Affymetrix Proprietary Database
# AFFX-r2-Bs-thr-3_s_at    Control sequence   Affymetrix Proprietary Database
# AFFX-r2-Bs-thr-5_s_at    Control sequence   Affymetrix Proprietary Database
# AFFX-r2-Bs-thr-M_s_at    Control sequence   Affymetrix Proprietary Database
# AFFX-r2-Ec-bioB-3_at     Control sequence   Affymetrix Proprietary Database
# AFFX-r2-Ec-bioB-5_at     Control sequence   Affymetrix Proprietary Database
# AFFX-r2-Ec-bioB-M_at     Control sequence   Affymetrix Proprietary Database
# AFFX-r2-Ec-bioC-3_at     Control sequence   Affymetrix Proprietary Database
# AFFX-r2-Ec-bioC-5_at     Control sequence   Affymetrix Proprietary Database
# AFFX-r2-Ec-bioD-3_at     Control sequence   Affymetrix Proprietary Database
# AFFX-r2-Ec-bioD-5_at     Control sequence   Affymetrix Proprietary Database
# AFFX-r2-Hs18SrRNA-3_s_at Control sequence   Affymetrix Proprietary Database
# AFFX-r2-Hs18SrRNA-5_at   Control sequence   Affymetrix Proprietary Database
# AFFX-r2-Hs18SrRNA-M_x_at Control sequence   Affymetrix Proprietary Database
# AFFX-r2-Hs28SrRNA-3_at   Control sequence   Affymetrix Proprietary Database
# AFFX-r2-Hs28SrRNA-5_at   Control sequence   Affymetrix Proprietary Database
# AFFX-r2-Hs28SrRNA-M_at   Control sequence   Affymetrix Proprietary Database
# AFFX-r2-P1-cre-3_at      Control sequence   Affymetrix Proprietary Database
# AFFX-r2-P1-cre-5_at      Control sequence   Affymetrix Proprietary Database
# AFFX-ThrX-3_at           Control sequence   Affymetrix Proprietary Database
# AFFX-ThrX-5_at           Control sequence   Affymetrix Proprietary Database
# AFFX-ThrX-M_at           Control sequence   Affymetrix Proprietary Database
# AFFX-TrpnX-3_at          Control sequence   Affymetrix Proprietary Database
# AFFX-TrpnX-5_at          Control sequence   Affymetrix Proprietary Database
# AFFX-TrpnX-M_at          Control sequence   Affymetrix Proprietary Database
#                          Target Description
# 1007_s_at                U48705 /FEATURE=mRNA /DEFINITION=HSU48705 Human receptor tyrosine kinase DDR gene, complete cds
# 1053_at                  M87338 /FEATURE= /DEFINITION=HUMA1SBU Human replication factor C, 40-kDa subunit (A1) mRNA, complete cds
# 117_at                   X51757 /FEATURE=cds /DEFINITION=HSP70B Human heat-shock protein HSP70B' gene
# 121_at                   X69699 /FEATURE= /DEFINITION=HSPAX8A H.sapiens Pax8 mRNA
# 1255_g_at                L36861 /FEATURE=expanded_cds /DEFINITION=HUMGCAPB Homo sapiens guanylate cyclase activating protein (GCAP) gene exons 1-4, complete cds
# 1294_at                  L13852 /FEATURE= /DEFINITION=HUME1URP Homo sapiens ubiquitin-activating enzyme E1 related protein mRNA, complete cds
# 1316_at                  X55005 /FEATURE=mRNA /DEFINITION=HSCERBAR Homo sapiens mRNA for thyroid hormone receptor alpha 1 THRA1, (c-erbA-1 gene)
# 1320_at                  X79510 /FEATURE=cds /DEFINITION=HSPTPD1 H.sapiens mRNA for protein-tyrosine-phosphatase D1
# 1405_i_at                M21121 /FEATURE= /DEFINITION=HUMTCSM Human T cell-specific protein (RANTES) mRNA, complete cds
# 1431_at                  J02843 /FEATURE=cds /DEFINITION=HUMCYPIIE Human cytochrome P450IIE1 (ethanol-inducible) gene, complete cds
# 1438_at                  X75208 /FEATURE=cds /DEFINITION=HSPTKR H.sapiens HEK2 mRNA for protein tyrosine kinase receptor
# 1487_at                  L38487 /FEATURE=mRNA /DEFINITION=HUMHERRA1 Human estrogen receptor-related protein (hERRa1) mRNA, 3' end, partial cds
# 1494_f_at                M33318 /FEATURE=mRNA /DEFINITION=HUMCPIIA3A Human cytochrome P450IIA3 (CYP2A3) mRNA, complete cds
# 1598_g_at                L13720 /FEATURE= /DEFINITION=HUMGAS Homo sapiens growth-arrest-specific protein (gas) mRNA, complete cds
# 160020_at                Z48481 /FEATURE=cds /DEFINITION=HSMMPM1 H.sapiens mRNA for membrane-type matrix metalloproteinase 1 /NOTE=replacement of probe set 1301_s_at
# 1729_at                  L41690 /FEATURE= /DEFINITION=HUMTRADD Homo sapiens TNF receptor-1 associated protein (TRADD) mRNA, 3' end of cds
# 1773_at                  L00635 /FEATURE= /DEFINITION=HUMFPTB Human farnesyl-protein transferase beta-subunit mRNA, complete cds
# 177_at                   U38545 /FEATURE= /DEFINITION=HSU38545 Human ARF-activated phosphatidylcholine-specific phospholipase D1a (hPLD1) mRNA, complete cds
# 179_at                   U38980 /FEATURE= /DEFINITION=U38980 Human PMS2 related (hPMSR6) mRNA,  complete cds
# 1861_at                  U66879 /FEATURE= /DEFINITION=HSU66879 Human Bcl-2 binding component 6 (bbc6) mRNA, complete cds
# 200000_s_at              gb:NM_006445.1 /DEF=Homo sapiens U5 snRNP-specific protein (220 kD), ortholog of S. cerevisiae Prp8p (PRP8), mRNA.  /FEA=mRNA /GEN=PRP8 /PROD=U5 snRNP-specific protein (220 kD), ortholog ofS. cerevisiae Prp8p /DB_XREF=gi:5453983 /UG=Hs.181368 U5 snRNP-specific protein (220 kD), ortholog of S. cerevisiae Prp8
DEF=Bacillus subtillis sporulation protein (spoOB), GTP-binding protein (obg), phenylalanine biosynthesis associated protein (pheB), and monofunctional prephenate dehydratase (pheA) genes, complete cds.
# AFFX-r2-Bs-phe-M_at      B. subtilis /GEN=pheA /DB_XREF=gb:M24537.1 /NOTE=SIF corresponding to nucleotides 2484-2875 of gb:M24537.1 /DEF=Bacillus subtillis sporulation protein (spoOB), GTP-binding protein (obg), phenylalanine biosynthesis associated protein (pheB), and monofunctional prephenate dehydratase (pheA) genes, complete cds.
# AFFX-r2-Bs-thr-3_s_at    B. subtilis /GEN=thrB /DB_XREF=gb:X04603.1 /NOTE=SIF corresponding to nucleotides 1735-2143 of gb:X04603.1 /DEF=B. subtilis thrB and thrC genes for homoserine kinase and threonine synthase.
# AFFX-r2-Bs-thr-5_s_at    B. subtilis /GEN=thrC /DB_XREF=gb:X04603.1 /NOTE=SIF corresponding to nucleotides 290-888 of gb:X04603.1 /DEF=B. subtilis thrB and thrC genes for homoserine kinase and threonine synthase.
# AFFX-r2-Bs-thr-M_s_at    B. subtilis /GEN=thrC, thrB /DB_XREF=gb:X04603.1 /NOTE=SIF corresponding to nucleotides 1045-1556 of gb:X04603.1 /DEF=B. subtilis thrB and thrC genes for homoserine kinase and threonine synthase.
# AFFX-r2-Ec-bioB-3_at     E. coli /GEN=bioB /DB_XREF=gb:J04423.1 /NOTE=SIF corresponding to nucleotides 2772-3004 of gb:J04423.1 /DEF=E.coli 7,8-diamino-pelargonic acid (bioA), biotin synthetase (bioB), 7-keto-8-amino-pelargonic acid synthetase (bioF), bioC protein, and dethiobiotin synthetase (bioD), complete cds.
# AFFX-r2-Ec-bioB-5_at     E. coli /GEN=bioB /DB_XREF=gb:J04423.1 /NOTE=SIF corresponding to nucleotides 2071-2304 of gb:J04423.1 /DEF=E.coli 7,8-diamino-pelargonic acid (bioA), biotin synthetase (bioB), 7-keto-8-amino-pelargonic acid synthetase (bioF), bioC protein, and dethiobiotin synthetase (bioD), complete cds.
# AFFX-r2-Ec-bioB-M_at     E. coli /GEN=bioB /DB_XREF=gb:J04423.1 /NOTE=SIF corresponding to nucleotides 2393-2682 of gb:J04423.1 /DEF=E.coli 7,8-diamino-pelargonic acid (bioA), biotin synthetase (bioB), 7-keto-8-amino-pelargonic acid synthetase (bioF), bioC protein, and dethiobiotin synthetase (bioD), complete cds.
# AFFX-r2-Ec-bioC-3_at     E. coli /GEN=bioC /DB_XREF=gb:J04423.1 /NOTE=SIF corresponding to nucleotides 4608-4883 of gb:J04423.1 /DEF=E.coli 7,8-diamino-pelargonic acid (bioA), biotin synthetase (bioB), 7-keto-8-amino-pelargonic acid synthetase (bioF), bioC protein, and dethiobiotin synthetase (bioD), complete cds.
# AFFX-r2-Ec-bioC-5_at     E. coli /GEN=bioC /DB_XREF=gb:J04423.1 /NOTE=SIF corresponding to nucleotides 4257-4573 of gb:J04423.1 /DEF=E.coli 7,8-diamino-pelargonic acid (bioA), biotin synthetase (bioB), 7-keto-8-amino-pelargonic acid synthetase (bioF), bioC protein, and dethiobiotin synthetase (bioD), complete cds.
# AFFX-r2-Ec-bioD-3_at     E. coli /GEN=bioD /DB_XREF=gb:J04423.1 /NOTE=SIF corresponding to nucleotides 5312-5559 of gb:J04423.1, not 100% identical /DEF=E.coli 7,8-diamino-pelargonic acid (bioA), biotin synthetase (bioB), 7-keto-8-amino-pelargonic acid synthetase (bioF), bioC protein, and dethiobiotin synthetase (bioD), complete cds.
# AFFX-r2-Ec-bioD-5_at     E. coli /GEN=bioD /DB_XREF=gb:J04423.1 /NOTE=SIF corresponding to nucleotides 5024-5244 of gb:J04423.1 /DEF=E.coli 7,8-diamino-pelargonic acid (bioA), biotin synthetase (bioB), 7-keto-8-amino-pelargonic acid synthetase (bioF), bioC protein, and dethiobiotin synthetase (bioD), complete cds.
# AFFX-r2-Hs18SrRNA-3_s_at M10098.1 Human 18S rRNA sequence, length 1969 bases, 3 prime target bases 1293-1938
# AFFX-r2-Hs18SrRNA-5_at   M10098.1 Human 18S rRNA sequence, length 1969 bases, 5 prime target bases 1-646
# AFFX-r2-Hs18SrRNA-M_x_at M10098.1 Human 18S rRNA sequence, length 1969 bases, middle target bases 647-1292
# AFFX-r2-Hs28SrRNA-3_at   M11167.1 Human 28S rRNA sequence, length 5025 bases, middle target bases 1666-3330
# AFFX-r2-Hs28SrRNA-5_at   M11167.1 Human 28S rRNA sequence, length 5025 bases, 5 prime target bases 1-1665
# AFFX-r2-Hs28SrRNA-M_at   M11167.1 Human 28S rRNA sequence, length 5025 bases, 3 prime target bases 3331-4995
# AFFX-r2-P1-cre-3_at      Bacteriophage P1 /GEN=cre /DB_XREF=gb:X03453.1 /NOTE=SIF corresponding to nucleotides 1032-1270 of gb:X03453.1 /DEF=Bacteriophage P1 cre gene for recombinase protein.
# AFFX-r2-P1-cre-5_at      Bacteriophage P1 /GEN=cre /DB_XREF=gb:X03453.1 /NOTE=SIF corresponding to nucleotides 581-1001 of gb:X03453.1 /DEF=Bacteriophage P1 cre gene for recombinase protein.
# AFFX-ThrX-3_at           B. subtilis /GEN=thrB /DB_XREF=gb:X04603.1 /NOTE=SIF corresponding to nucleotides 1689-2151 of gb:X04603.1 /DEF=B. subtilis thrB and thrC genes for homoserine kinase and threonine synthase (EC 2.7.1.39 and EC 4.2.99.2, respectively).
# AFFX-ThrX-5_at           B. subtilis /GEN=thrC /DB_XREF=gb:X04603.1 /NOTE=SIF corresponding to nucleotides 288-932 of gb:X04603.1 /DEF=B. subtilis thrB and thrC genes for homoserine kinase and threonine synthase (EC 2.7.1.39 and EC 4.2.99.2, respectively).
# AFFX-ThrX-M_at           B. subtilis /GEN=thrC, thrB /DB_XREF=gb:X04603.1 /NOTE=SIF corresponding to nucleotides 995-1562 of gb:X04603.1, not 100% identical /DEF=B. subtilis thrB and thrC genes for homoserine kinase and threonine synthase (EC 2.7.1.39 and EC 4.2.99.2, respectively).
# AFFX-TrpnX-3_at          B. subtilis /GEN=trpC, trpF /DB_XREF=gb:K01391.1 /NOTE=SIF corresponding to nucleotides 3790-4368 of gb:K01391.1, not 100% identical /DEF=B.subtilis tryptophan (trp) operon, complete cds.
# AFFX-TrpnX-5_at          B. subtilis /GEN=trpE, trpD /DB_XREF=gb:K01391.1 /NOTE=SIF corresponding to nucleotides 1953-2483 of gb:K01391.1, not 100% identical /DEF=B.subtilis tryptophan (trp) operon, complete cds.
# AFFX-TrpnX-M_at          B. subtilis /GEN=trpD, trpC /DB_XREF=gb:K01391.1 /NOTE=SIF corresponding to nucleotides 2880-3359 of gb:K01391.1, not 100% identical /DEF=B.subtilis tryptophan (trp) operon, complete cds.
#                          Representative Public ID
# 1007_s_at                U48705
# 1053_at                  M87338
# 117_at                   X51757
# 121_at                   X69699
# 1255_g_at                L36861
# 1294_at                  L13852
# 1316_at                  X55005
# 1320_at                  X79510
# 1405_i_at                M21121
# 1431_at                  J02843
# 1438_at                  X75208
# 1487_at                  L38487
# 1494_f_at                M33318
# 1598_g_at                L13720
# 160020_at                Z48481
# 1729_at                  L41690
# 1773_at                  L00635
# 177_at                   U38545
# 179_at                   U38980
# 1861_at                  U66879
# 200000_s_at              NM_006445
# 200001_at                NM_001749
# 200002_at                NM_007209
# 200003_s_at              NM_000991
# 200004_at                NM_001418
# 200005_at                NM_003753
# 200006_at                NM_007262
# 200007_at                NM_003134
# 200008_s_at              D13988
# 200009_at                NM_001494
# ⋮                        ⋮
# AFFX-r2-Bs-lys-3_at      AFFX-r2-Bs-lys-3
# AFFX-r2-Bs-lys-5_at      AFFX-r2-Bs-lys-5
# AFFX-r2-Bs-lys-M_at      AFFX-r2-Bs-lys-M
# AFFX-r2-Bs-phe-3_at      AFFX-r2-Bs-phe-3
# AFFX-r2-Bs-phe-5_at      AFFX-r2-Bs-phe-5
# AFFX-r2-Bs-phe-M_at      AFFX-r2-Bs-phe-M
# AFFX-r2-Bs-thr-3_s_at    AFFX-r2-Bs-thr-3
# AFFX-r2-Bs-thr-5_s_at    AFFX-r2-Bs-thr-5
# AFFX-r2-Bs-thr-M_s_at    AFFX-r2-Bs-thr-M
# AFFX-r2-Ec-bioB-3_at     AFFX-r2-Ec-bioB-3
# AFFX-r2-Ec-bioB-5_at     AFFX-r2-Ec-bioB-5
# AFFX-r2-Ec-bioB-M_at     AFFX-r2-Ec-bioB-M
# AFFX-r2-Ec-bioC-3_at     AFFX-r2-Ec-bioC-3
# AFFX-r2-Ec-bioC-5_at     AFFX-r2-Ec-bioC-5
# AFFX-r2-Ec-bioD-3_at     AFFX-r2-Ec-bioD-3
# AFFX-r2-Ec-bioD-5_at     AFFX-r2-Ec-bioD-5
# AFFX-r2-Hs18SrRNA-3_s_at AFFX-r2-Hs18SrRNA-3
# AFFX-r2-Hs18SrRNA-5_at   AFFX-r2-Hs18SrRNA-5
# AFFX-r2-Hs18SrRNA-M_x_at AFFX-r2-Hs18SrRNA-M
# AFFX-r2-Hs28SrRNA-3_at   AFFX-r2-Hs28SrRNA-3
# AFFX-r2-Hs28SrRNA-5_at   AFFX-r2-Hs28SrRNA-5
# AFFX-r2-Hs28SrRNA-M_at   AFFX-r2-Hs28SrRNA-M
# AFFX-r2-P1-cre-3_at      AFFX-r2-P1-cre-3
# AFFX-r2-P1-cre-5_at      AFFX-r2-P1-cre-5
# AFFX-ThrX-3_at           AFFX-ThrX-3
# AFFX-ThrX-5_at           AFFX-ThrX-5
# AFFX-ThrX-M_at           AFFX-ThrX-M
# AFFX-TrpnX-3_at          AFFX-TrpnX-3
# AFFX-TrpnX-5_at          AFFX-TrpnX-5
# AFFX-TrpnX-M_at          AFFX-TrpnX-M
#                          Gene Title
# 1007_s_at                discoidin domain receptor tyrosine kinase 1 /// microRNA 4640
# 1053_at                  replication factor C (activator 1) 2, 40kDa
# 117_at                   heat shock 70kDa protein 6 (HSP70B')
# 121_at                   paired box 8
# 1255_g_at                guanylate cyclase activator 1A (retina)
# 1294_at                  microRNA 5193 /// ubiquitin-like modifier activating enzyme 7
# 1316_at                  thyroid hormone receptor, alpha
# 1320_at                  protein tyrosine phosphatase, non-receptor type 21
# 1405_i_at                chemokine (C-C motif) ligand 5
# 1431_at                  cytochrome P450, family 2, subfamily E, polypeptide 1
# 1438_at                  EPH receptor B3
# 1487_at                  estrogen-related receptor alpha
# 1494_f_at                cytochrome P450, family 2, subfamily A, polypeptide 6
# 1598_g_at                growth arrest-specific 6
# 160020_at                matrix metallopeptidase 14 (membrane-inserted)
# 1729_at                  TNFRSF1A-associated via death domain
# 1773_at                  CHURC1-FNTB readthrough /// farnesyltransferase, CAAX box, beta
# 177_at                   phospholipase D1, phosphatidylcholine-specific
# 179_at                   DTX2P1-UPK3BP1-PMS2P11 readthrough transcribed pseudogene
# 1861_at                  BCL2-associated agonist of cell death
# 200000_s_at              pre-mRNA processing factor 8
# 200001_at                calpain, small subunit 1
# 200002_at                ribosomal protein L35
# 200003_s_at              microRNA 6805 /// ribosomal protein L28
# 200004_at                eukaryotic translation initiation factor 4 gamma, 2
# 200005_at                eukaryotic translation initiation factor 3, subunit D
# 200006_at                parkinson protein 7
# 200007_at                signal recognition particle 14kDa (homologous Alu RNA binding protein)
# 200008_s_at              GDP dissociation inhibitor 2
# 200009_at                GDP dissociation inhibitor 2
# ⋮                        ⋮
# AFFX-r2-Bs-lys-3_at
# AFFX-r2-Bs-lys-5_at
# AFFX-r2-Bs-lys-M_at
# AFFX-r2-Bs-phe-3_at
# AFFX-r2-Bs-phe-5_at
# AFFX-r2-Bs-phe-M_at
# AFFX-r2-Bs-thr-3_s_at
# AFFX-r2-Bs-thr-5_s_at
# AFFX-r2-Bs-thr-M_s_at
# AFFX-r2-Ec-bioB-3_at
# AFFX-r2-Ec-bioB-5_at
# AFFX-r2-Ec-bioB-M_at
# AFFX-r2-Ec-bioC-3_at
# AFFX-r2-Ec-bioC-5_at
# AFFX-r2-Ec-bioD-3_at
# AFFX-r2-Ec-bioD-5_at
# AFFX-r2-Hs18SrRNA-3_s_at
# AFFX-r2-Hs18SrRNA-5_at
# AFFX-r2-Hs18SrRNA-M_x_at
# AFFX-r2-Hs28SrRNA-3_at
# AFFX-r2-Hs28SrRNA-5_at
# AFFX-r2-Hs28SrRNA-M_at
# AFFX-r2-P1-cre-3_at
# AFFX-r2-P1-cre-5_at
# AFFX-ThrX-3_at
# AFFX-ThrX-5_at
# AFFX-ThrX-M_at
# AFFX-TrpnX-3_at
# AFFX-TrpnX-5_at
# AFFX-TrpnX-M_at
#                          Gene Symbol            ENTREZ_GENE_ID
# 1007_s_at                DDR1 /// MIR4640       780 /// 100616237
# 1053_at                  RFC2                   5982
# 117_at                   HSPA6                  3310
# 121_at                   PAX8                   7849
# 1255_g_at                GUCA1A                 2978
# 1294_at                  MIR5193 /// UBA7       7318 /// 100847079
# 1316_at                  THRA                   7067
# 1320_at                  PTPN21                 11099
# 1405_i_at                CCL5                   6352
# 1431_at                  CYP2E1                 1571
# 1438_at                  EPHB3                  2049
# 1487_at                  ESRRA                  2101
# 1494_f_at                CYP2A6                 1548
# ...
# AFFX-r2-P1-cre-5_at
# AFFX-ThrX-3_at
# AFFX-ThrX-5_at
# AFFX-ThrX-M_at
# AFFX-TrpnX-3_at
# AFFX-TrpnX-5_at
# AFFX-TrpnX-M_at

# %% [markdown]
# Inspecione as colunas e selecione as que lhe interessa. Nesse caso, escolheremos as colunas: `GB_ACC`, `Sequence Source`, `Gene Symbol`, `ENTREZ_GENE_ID` e `RefSeq Transcript ID`.

# %%
### Look at the features data frame and decide the names of the columns you want to keep
features <- select(features,"GB_ACC", "Sequence Source", "Gene Symbol", "ENTREZ_GENE_ID", "RefSeq Transcript ID")
full_output <- cbind(features,exprs(gse))
write_csv(full_output, file="gse_full_output.csv")

# %% [markdown]
# ## Expressão Diferencial
#
# De longe, o pacote mais popular para realizar expressão diferencial é o `limma`. O guia do usuário é extenso e cobre a teoria por trás da análise e muitos casos de uso [(Capítulos 9 e 17 para dados de canal único, como Illumina e Affymetrix)](https://bioconductor.org/packages/release/bioc/vignettes/limma/inst/doc/usersguide.pdf)
#
# Crucialmente, temos que alocar as amostras em nosso conjunto de dados para os grupos de amostras de interesse. Uma função útil é `model.matrix`, que criará uma matriz de design a partir de uma das colunas em seu `sampleInfo`. Aqui escolheremos `sampleInfo$State`.
#
# A matriz de design é uma matriz de 0s e 1s; uma linha para cada amostra e uma coluna para cada grupo de amostras. Um 1 em uma linha e coluna específicas indica que uma determinada amostra (a linha) pertence a um determinado grupo (coluna).

# %%
library(limma)
design <- model.matrix(~0+sampleInfo$State)
design
# Out:
# Attaching package: ‘limma’
#
#
# The following object is masked from ‘package:BiocGenerics’:
#
#     plotMA
#    sampleInfo$Statecontrol sampleInfo$Statenephrosclerosis
# 1  0                       1
# 2  0                       1
# 3  0                       1
# 4  0                       1
# 5  0                       1
# 6  0                       1
# 7  0                       1
# 8  0                       1
# 9  0                       1
# 10 0                       1
# 11 0                       1
# 12 0                       1
# 13 0                       1
# 14 0                       1
# 15 1                       0
# 16 1                       0
# 17 1                       0
# 18 1                       0

# %% [markdown]
# As colunas acima estão com o nome muito complexo. Vamos simplificá-lo usando o comando abaixo:

# %%
## the column names are a bit ugly, so we will rename
colnames(design) <- c("Control","Nephrosclerosis")
design
# Out:
#    Control Nephrosclerosis
# 1  0       1
# 2  0       1
# 3  0       1
# 4  0       1
# 5  0       1
# 6  0       1
# 7  0       1
# 8  0       1
# 9  0       1
# 10 0       1
# 11 0       1
# 12 0       1
# 13 0       1
# 14 0       1
# 15 1       0
# 16 1       0
# 17 1       0
# 18 1       0

# %% [markdown]
# O poder de detectar expressão diferencial pode ser melhorado se filtrarmos genes pouco expressos antes de realizar a análise. A maneira como se define um gene sendo expresso pode variar de experimento para experimento, então um limite que funcionará para todos os conjuntos de dados não é viável. Aqui consideramos que cerca de 50% dos genes não serão expressos e usamos o nível de expressão mediana como um limite.

# %%
summary(exprs(gse))

## calculate median expression level
cutoff <- median(exprs(gse))

## TRUE or FALSE for whether each gene is "expressed" in each sample
is_expressed <- exprs(gse) > cutoff

## Identify genes expressed in more than 2 samples

keep <- rowSums(is_expressed) > 2

## check how many genes are removed / retained.
table(keep)

## subset to just those expressed genes
gse <- gse[keep,]
# Out:
#    GSM517355        GSM517356        GSM517357        GSM517358
#  Min.   : 3.597   Min.   : 3.616   Min.   : 3.630   Min.   : 3.660
#  1st Qu.: 5.870   1st Qu.: 5.888   1st Qu.: 5.952   1st Qu.: 5.914
#  Median : 7.252   Median : 7.261   Median : 7.271   Median : 7.258
#  Mean   : 7.509   Mean   : 7.502   Mean   : 7.529   Mean   : 7.507
#  3rd Qu.: 8.996   3rd Qu.: 8.946   3rd Qu.: 8.930   3rd Qu.: 8.922
#  Max.   :14.394   Max.   :14.425   Max.   :14.390   Max.   :14.436
#    GSM517359        GSM517360        GSM517361        GSM517362
#  Min.   : 3.632   Min.   : 3.639   Min.   : 3.556   Min.   : 3.526
#  1st Qu.: 5.842   1st Qu.: 5.916   1st Qu.: 5.885   1st Qu.: 5.833
#  Median : 7.255   Median : 7.274   Median : 7.266   Median : 7.249
#  Mean   : 7.495   Mean   : 7.503   Mean   : 7.503   Mean   : 7.496
#  3rd Qu.: 8.971   3rd Qu.: 8.911   3rd Qu.: 8.950   3rd Qu.: 8.984
#  Max.   :14.435   Max.   :14.397   Max.   :14.395   Max.   :14.412
#    GSM517363        GSM517364        GSM517365        GSM517366
#  Min.   : 3.609   Min.   : 3.634   Min.   : 3.638   Min.   : 3.660
#  1st Qu.: 5.820   1st Qu.: 5.892   1st Qu.: 5.874   1st Qu.: 5.874
#  Median : 7.224   Median : 7.258   Median : 7.259   Median : 7.234
#  Mean   : 7.489   Mean   : 7.497   Mean   : 7.506   Mean   : 7.499
#  3rd Qu.: 8.973   3rd Qu.: 8.914   3rd Qu.: 8.955   3rd Qu.: 8.938
#  Max.   :14.503   Max.   :14.484   Max.   :14.377   Max.   :14.426
#    GSM517367        GSM517368        GSM517369        GSM517370
#  Min.   : 3.609   Min.   : 3.669   Min.   : 3.672   Min.   : 3.687
#  1st Qu.: 5.810   1st Qu.: 5.879   1st Qu.: 6.008   1st Qu.: 6.010
#  Median : 7.220   Median : 7.240   Median : 7.300   Median : 7.301
#  Mean   : 7.489   Mean   : 7.502   Mean   : 7.516   Mean   : 7.509
#  3rd Qu.: 8.988   3rd Qu.: 8.938   3rd Qu.: 8.840   3rd Qu.: 8.810
#  Max.   :14.348   Max.   :14.376   Max.   :14.332   Max.   :14.532
#    GSM517371        GSM517372
#  Min.   : 3.628   Min.   : 3.613
#  1st Qu.: 5.920   1st Qu.: 5.966
#  Median : 7.255   Median : 7.277
#  Mean   : 7.498   Mean   : 7.502
#  3rd Qu.: 8.890   3rd Qu.: 8.846
#  Max.   :14.533   Max.   :14.416
# keep
# FALSE  TRUE
# 10041 12242

# %% [markdown]
# A função `lmFit` é usada para ajustar o modelo aos dados. O resultado disso é estimar o nível de expressão em cada um dos grupos que especificamos.

# %%
fit <- lmFit(exprs(gse), design)
head(fit$coefficients)
# Out:
#           Control   Nephrosclerosis
# 1007_s_at 11.096270 10.937513
# 121_at    11.440960 10.540703
# 1294_at    8.771636  9.065209
# 1405_i_at  6.321916  6.865027
# 1487_at    8.577031  8.279861
# 1494_f_at  7.412815  7.180977

# %% [markdown]
# Para realizar a análise diferencial, temos que definir o contraste de nosso interesse. No nosso caso, temos apenas dois grupos e um contraste de interesse. Múltiplos contrastes podem ser definidos na função `makeContrasts`.

# %%
contrasts <- makeContrasts(Nephrosclerosis - Control, levels=design)

## can define multiple contrasts
## e.g. makeContrasts(Group1 - Group2, Group2 - Group3,....levels=design)

fit2 <- contrasts.fit(fit, contrasts)

# %% [markdown]
# Finalmente, aplique o passo de Bayes empírico para obter as estatísticas de expressão diferencial e valores-p.

# %%
fit2 <- eBayes(fit2)

# %% [markdown]
# Normalmente, damos nossa primeira olhada nos resultados usando o comando `topTable`. Isso nos fornece uma tabela dos genes mais diferencialmente expressos, juntamente com estatísticas associadas.

# %%
topTable(fit2)
# Out:
#             logFC      AveExpr   t          P.Value      adj.P.Val    B
# 204220_at    1.2338294  9.241031  10.719353 1.821613e-09 1.333217e-05 11.801993
# 201693_s_at -1.7042057  7.413416 -10.602572 2.178104e-09 1.333217e-05 11.637477
# 202659_at    1.0187782  9.643952   9.764569 8.201093e-09 2.185198e-05 10.407000
# 201694_s_at -2.7719768  9.824949  -9.610962 1.054693e-08 2.185198e-05 10.171632
# 200653_s_at  0.7697343  9.010519   9.522224 1.221193e-08 2.185198e-05 10.034232
# 202303_x_at  0.6836935  8.636306   9.463128 1.347102e-08 2.185198e-05  9.942143
# 208743_s_at  0.9388022  9.434581   9.438272 1.404038e-08 2.185198e-05  9.903269
# 209572_s_at  1.1675780  8.599309   9.407221 1.478706e-08 2.185198e-05  9.854590
# 213620_s_at  1.6759957 12.002049   9.302027 1.763959e-08 2.185198e-05  9.688704
# 213139_at    1.4177989 10.048226   9.294983 1.785001e-08 2.185198e-05  9.677543

# %% [markdown]
# A função `topTable` exibe automaticamente os resultados para o primeiro contraste. Se você quiser ver resultados para outros contrastes, você pode especificar o contraste de interesse como um argumento para a função topTable. Por exemplo, se você tiver um segundo contraste que você gostaria de ver, você pode usar `topTable(fit, coef=2)`, onde `fit` é o objeto ajustado do `limma` e `coef=2` especifica o segundo contraste. Lembre-se de que a contagem de coeficientes começa em 1 para o primeiro contraste.
#
# Portanto, só execute os comandos abaixo se você tiver mais de um contraste.

# %%
topTable(fit2, coef=1)
### to see the results of the second contrast (if it exists)
## topTable(fit2, coef=2)

# %% [markdown]
# A função `decideTests` é muito útil para determinar o número geral de genes diferencialmente expressos. Ela retorna uma matriz com os mesmos genes e contrastes que o objeto ajustado, mas cada entrada é -1, 0 ou 1. Um -1 indica que o gene é significativamente subexpresso (*downregulated*) no contraste correspondente, um 1 indica que o gene é significativamente superexpresso (*upregulated), e um 0 indica que não há evidência de expressão diferencial para esse gene no contraste correspondente. Você pode somar o número de -1s e 1s para obter o número total de genes diferencialmente expressos.

# %%
decideTests(fit2)
# Out:
#                             Nephrosclerosis - Control
# 1007_s_at                    0
# 121_at                      -1
# 1294_at                      0
# 1405_i_at                    0
# 1487_at                     -1
# 1494_f_at                   -1
# 1598_g_at                    1
# 160020_at                   -1
# 1729_at                      0
# 179_at                      -1
# 1861_at                      1
# 200000_s_at                  0
# 200001_at                    0
# 200002_at                    1
# 200003_s_at                  1
# 200004_at                    1
# 200005_at                    1
# 200006_at                    0
# 200007_at                    0
# 200008_s_at                  0
# 200009_at                    0
# 200010_at                    0
# 200011_s_at                  0
# 200012_x_at                  0
# 200013_at                    0
# 200014_s_at                  1
# 200015_s_at                  0
# 200016_x_at                  0
# 200017_at                    0
# 200018_at                    0
# ⋮                           ⋮
# AFFX-HSAC07/X00351_5_at      0
# AFFX-HSAC07/X00351_M_at      0
# AFFX-hum_alu_at             -1
# AFFX-HUMGAPDH/M33197_3_at    0
# AFFX-HUMGAPDH/M33197_5_at    0
# AFFX-HUMGAPDH/M33197_M_at    0
# AFFX-HUMISGF3A/M97935_3_at   0
# AFFX-HUMISGF3A/M97935_MA_at  0
# AFFX-HUMISGF3A/M97935_MB_at  0
# AFFX-HUMRGE/M10098_3_at      0
# AFFX-HUMRGE/M10098_5_at      1
# AFFX-HUMRGE/M10098_M_at      0
# AFFX-M27830_3_at             0
# AFFX-M27830_5_at            -1
# AFFX-M27830_M_at            -1
# AFFX-r2-Ec-bioB-3_at         0
# AFFX-r2-Ec-bioB-5_at         0
# AFFX-r2-Ec-bioB-M_at         0
# AFFX-r2-Ec-bioC-3_at         0
# AFFX-r2-Ec-bioC-5_at         0
# AFFX-r2-Ec-bioD-3_at         0
# AFFX-r2-Ec-bioD-5_at         0
# AFFX-r2-Hs18SrRNA-3_s_at     0
# AFFX-r2-Hs18SrRNA-5_at       1
# AFFX-r2-Hs18SrRNA-M_x_at     0
# AFFX-r2-Hs28SrRNA-3_at       0
# AFFX-r2-Hs28SrRNA-5_at       0
# AFFX-r2-Hs28SrRNA-M_at       0
# AFFX-r2-P1-cre-3_at          0
# AFFX-r2-P1-cre-5_at          0

# %% [markdown]
# Para ver os totais, só executar o comando abaixo:

# %%
table(decideTests(fit2))
# Out:
#   -1    0    1
# 1380 8185 2677

# %% [markdown]
# ### Lidando com os *outliers*
#
# É tentador descartar quaisquer arrays que pareçam ser *outliers* antes das expressões diferenciais. No entanto, isso é feito à custa do tamanho da amostra, o que pode ser um problema para pequenos experimentos. Um compromisso, que tem se mostrado eficaz, é calcular pesos para definir a confiabilidade de cada amostra ([Ritchie et al. 2006](http://www.biomedcentral.com/1471-2105/7/261)).
#
# A função `arrayWeights` atribuirá uma pontuação a cada amostra; com um valor de 1 implicando peso igual. Amostras com pontuação menor que 1 são rebaixadas, e amostras com pontuações maiores que 1 são valorizadas. Portanto, nenhuma amostra realmente precisa ser removida, pelo menos não nessa série exemplo.
#
# Só execute as próximas duas células com código se você quiser adicionar pesos a função.

# %%
## calculate relative array weights
# aw <- arrayWeights(exprs(gse),design)
# aw

# %% [markdown]
# A função `lmfit` aceita esses pesos, e o resto do código pode ser excutado da mesma forma que acima.

# %%
# fit <- lmFit(exprs(gse), design,
#             weights = aw)
# contrasts <- makeContrasts(Nephrosclerosis - Control, levels=design)
# fit2 <- contrasts.fit(fit, contrasts)
# fit2 <- eBayes(fit2)

# %% [markdown]
# ## Processamento adicional e visualização dos resultados e da Expressão Diferencial (DE)
#
# No momento, esses resultados não são particularmente fáceis de navegar, pois a única informação para identificar cada gene é o identificador que o fabricante do microarray atribuiu. Felizmente, a entrada GEO contém uma anotação extensa que podemos adicionar. Os dados de anotação podem ser recuperados com a função `fData` e restringimos às colunas de nosso interesse usando `select`.
#
# ***Para seus próprios dados, você terá que escolher as colunas que são de interesse para você. Provavelmente você não terá os mesmos cabeçalhos de coluna usados aqui.***
#
# Uma vez que um quadro de dados de anotação foi criado, ele pode ser atribuído aos nossos resultados.

# %%
anno <- fData(gse)
anno
# Out:
#                             ID                          GB_ACC    SPOT_ID
# 1007_s_at                   1007_s_at                   U48705
# 121_at                      121_at                      X69699
# 1294_at                     1294_at                     L13852
# 1405_i_at                   1405_i_at                   M21121
# 1487_at                     1487_at                     L38487
# 1494_f_at                   1494_f_at                   M33318
# 1598_g_at                   1598_g_at                   L13720
# 160020_at                   160020_at                   Z48481
# 1729_at                     1729_at                     L41690
# 179_at                      179_at                      U38980
# 1861_at                     1861_at                     U66879
# 200000_s_at                 200000_s_at                 NM_006445
# 200001_at                   200001_at                   NM_001749
# 200002_at                   200002_at                   NM_007209
# 200003_s_at                 200003_s_at                 NM_000991
# 200004_at                   200004_at                   NM_001418
# 200005_at                   200005_at                   NM_003753
# 200006_at                   200006_at                   NM_007262
# 200007_at                   200007_at                   NM_003134
# 200008_s_at                 200008_s_at                 D13988
# 200009_at                   200009_at                   NM_001494
# 200010_at                   200010_at                   NM_000975
# 200011_s_at                 200011_s_at                 NM_001659
# 200012_x_at                 200012_x_at                 NM_000982
# 200013_at                   200013_at                   NM_000986
# 200014_s_at                 200014_s_at                 NM_004500
# 200015_s_at                 200015_s_at                 NM_004404
# 200016_x_at                 200016_x_at                 NM_002136
# 200017_at                   200017_at                   NM_002954
# 200018_at                   200018_at                   NM_001017
# ⋮                           ⋮                           ⋮         ⋮
# AFFX-HSAC07/X00351_5_at     AFFX-HSAC07/X00351_5_at               --Control
# AFFX-HSAC07/X00351_M_at     AFFX-HSAC07/X00351_M_at               --Control
# AFFX-hum_alu_at             AFFX-hum_alu_at                       --Control
# AFFX-HUMGAPDH/M33197_3_at   AFFX-HUMGAPDH/M33197_3_at             --Control
# AFFX-HUMGAPDH/M33197_5_at   AFFX-HUMGAPDH/M33197_5_at             --Control
# AFFX-HUMGAPDH/M33197_M_at   AFFX-HUMGAPDH/M33197_M_at             --Control
# AFFX-HUMISGF3A/M97935_3_at  AFFX-HUMISGF3A/M97935_3_at            --Control
# AFFX-HUMISGF3A/M97935_MA_at AFFX-HUMISGF3A/M97935_MA_at           --Control
# AFFX-HUMISGF3A/M97935_MB_at AFFX-HUMISGF3A/M97935_MB_at           --Control
# AFFX-HUMRGE/M10098_3_at     AFFX-HUMRGE/M10098_3_at               --Control
# AFFX-HUMRGE/M10098_5_at     AFFX-HUMRGE/M10098_5_at               --Control
# AFFX-HUMRGE/M10098_M_at     AFFX-HUMRGE/M10098_M_at               --Control
# AFFX-M27830_3_at            AFFX-M27830_3_at                      --Control
# AFFX-M27830_5_at            AFFX-M27830_5_at                      --Control
# AFFX-M27830_M_at            AFFX-M27830_M_at                      --Control
# AFFX-r2-Ec-bioB-3_at        AFFX-r2-Ec-bioB-3_at                  --Control
# AFFX-r2-Ec-bioB-5_at        AFFX-r2-Ec-bioB-5_at                  --Control
# AFFX-r2-Ec-bioB-M_at        AFFX-r2-Ec-bioB-M_at                  --Control
# AFFX-r2-Ec-bioC-3_at        AFFX-r2-Ec-bioC-3_at                  --Control
# AFFX-r2-Ec-bioC-5_at        AFFX-r2-Ec-bioC-5_at                  --Control
# AFFX-r2-Ec-bioD-3_at        AFFX-r2-Ec-bioD-3_at                  --Control
# AFFX-r2-Ec-bioD-5_at        AFFX-r2-Ec-bioD-5_at                  --Control
# AFFX-r2-Hs18SrRNA-3_s_at    AFFX-r2-Hs18SrRNA-3_s_at              --Control
# AFFX-r2-Hs18SrRNA-5_at      AFFX-r2-Hs18SrRNA-5_at                --Control
# AFFX-r2-Hs18SrRNA-M_x_at    AFFX-r2-Hs18SrRNA-M_x_at              --Control
# AFFX-r2-Hs28SrRNA-3_at      AFFX-r2-Hs28SrRNA-3_at                --Control
# AFFX-r2-Hs28SrRNA-5_at      AFFX-r2-Hs28SrRNA-5_at                --Control
# AFFX-r2-Hs28SrRNA-M_at      AFFX-r2-Hs28SrRNA-M_at                --Control
# AFFX-r2-P1-cre-3_at         AFFX-r2-P1-cre-3_at                   --Control
# AFFX-r2-P1-cre-5_at         AFFX-r2-P1-cre-5_at                   --Control
#                             Species Scientific Name Annotation Date
# 1007_s_at                   Homo sapiens            Oct 6, 2014
# 121_at                      Homo sapiens            Oct 6, 2014
# 1294_at                     Homo sapiens            Oct 6, 2014
# 1405_i_at                   Homo sapiens            Oct 6, 2014
# 1487_at                     Homo sapiens            Oct 6, 2014
# 1494_f_at                   Homo sapiens            Oct 6, 2014
# 1598_g_at                   Homo sapiens            Oct 6, 2014
# 160020_at                   Homo sapiens            Oct 6, 2014
# 1729_at                     Homo sapiens            Oct 6, 2014
# 179_at                      Homo sapiens            Oct 6, 2014
# 1861_at                     Homo sapiens            Oct 6, 2014
# 200000_s_at                 Homo sapiens            Oct 6, 2014
# 200001_at                   Homo sapiens            Oct 6, 2014
# 200002_at                   Homo sapiens            Oct 6, 2014
# 200003_s_at                 Homo sapiens            Oct 6, 2014
# 200004_at                   Homo sapiens            Oct 6, 2014
# 200005_at                   Homo sapiens            Oct 6, 2014
# 200006_at                   Homo sapiens            Oct 6, 2014
# 200007_at                   Homo sapiens            Oct 6, 2014
# 200008_s_at                 Homo sapiens            Oct 6, 2014
# 200009_at                   Homo sapiens            Oct 6, 2014
# 200010_at                   Homo sapiens            Oct 6, 2014
# 200011_s_at                 Homo sapiens            Oct 6, 2014
# 200012_x_at                 Homo sapiens            Oct 6, 2014
# 200013_at                   Homo sapiens            Oct 6, 2014
# 200014_s_at                 Homo sapiens            Oct 6, 2014
# 200015_s_at                 Homo sapiens            Oct 6, 2014
# 200016_x_at                 Homo sapiens            Oct 6, 2014
# 200017_at                   Homo sapiens            Oct 6, 2014
# 200018_at                   Homo sapiens            Oct 6, 2014
# ⋮                           ⋮                       ⋮
# AFFX-HSAC07/X00351_5_at     Homo sapiens            Oct 6, 2014
# AFFX-HSAC07/X00351_M_at     Homo sapiens            Oct 6, 2014
# AFFX-hum_alu_at             Homo sapiens            Oct 6, 2014
# AFFX-HUMGAPDH/M33197_3_at   Homo sapiens            Oct 6, 2014
# AFFX-HUMGAPDH/M33197_5_at   Homo sapiens            Oct 6, 2014
# AFFX-HUMGAPDH/M33197_M_at   Homo sapiens            Oct 6, 2014
# AFFX-HUMISGF3A/M97935_3_at  Homo sapiens            Oct 6, 2014
# AFFX-HUMISGF3A/M97935_MA_at Homo sapiens            Oct 6, 2014
# AFFX-HUMISGF3A/M97935_MB_at Homo sapiens            Oct 6, 2014
# AFFX-HUMRGE/M10098_3_at     Homo sapiens            Oct 6, 2014
# AFFX-HUMRGE/M10098_5_at     Homo sapiens            Oct 6, 2014
# AFFX-HUMRGE/M10098_M_at     Homo sapiens            Oct 6, 2014
# AFFX-M27830_3_at            Homo sapiens            Oct 6, 2014
# AFFX-M27830_5_at            Homo sapiens            Oct 6, 2014
# AFFX-M27830_M_at            Homo sapiens            Oct 6, 2014
# AFFX-r2-Ec-bioB-3_at        Homo sapiens            Oct 6, 2014
# AFFX-r2-Ec-bioB-5_at        Homo sapiens            Oct 6, 2014
# AFFX-r2-Ec-bioB-M_at        Homo sapiens            Oct 6, 2014
# AFFX-r2-Ec-bioC-3_at        Homo sapiens            Oct 6, 2014
# AFFX-r2-Ec-bioC-5_at        Homo sapiens            Oct 6, 2014
# AFFX-r2-Ec-bioD-3_at        Homo sapiens            Oct 6, 2014
# AFFX-r2-Ec-bioD-5_at        Homo sapiens            Oct 6, 2014
# AFFX-r2-Hs18SrRNA-3_s_at    Homo sapiens            Oct 6, 2014
# AFFX-r2-Hs18SrRNA-5_at      Homo sapiens            Oct 6, 2014
# AFFX-r2-Hs18SrRNA-M_x_at    Homo sapiens            Oct 6, 2014
# AFFX-r2-Hs28SrRNA-3_at      Homo sapiens            Oct 6, 2014
# AFFX-r2-Hs28SrRNA-5_at      Homo sapiens            Oct 6, 2014
# AFFX-r2-Hs28SrRNA-M_at      Homo sapiens            Oct 6, 2014
# AFFX-r2-P1-cre-3_at         Homo sapiens            Oct 6, 2014
# AFFX-r2-P1-cre-5_at         Homo sapiens            Oct 6, 2014
#                             Sequence Type      Sequence Source
# 1007_s_at                   Exemplar sequence  Affymetrix Proprietary Database
# 121_at                      Exemplar sequence  GenBank
# 1294_at                     Exemplar sequence  GenBank
# 1405_i_at                   Exemplar sequence  GenBank
# 1487_at                     Exemplar sequence  Affymetrix Proprietary Database
# 1494_f_at                   Exemplar sequence  Affymetrix Proprietary Database
# 1598_g_at                   Exemplar sequence  GenBank
# 160020_at                   Consensus sequence GenBank
# 1729_at                     Exemplar sequence  GenBank
# 179_at                      Exemplar sequence  GenBank
# 1861_at                     Exemplar sequence  GenBank
# 200000_s_at                 Exemplar sequence  GenBank
# 200001_at                   Exemplar sequence  GenBank
# 200002_at                   Exemplar sequence  GenBank
# 200003_s_at                 Exemplar sequence  GenBank
# 200004_at                   Exemplar sequence  GenBank
# 200005_at                   Exemplar sequence  GenBank
# 200006_at                   Exemplar sequence  GenBank
# 200007_at                   Exemplar sequence  GenBank
# 200008_s_at                 Exemplar sequence  GenBank
# 200009_at                   Exemplar sequence  GenBank
# 200010_at                   Exemplar sequence  GenBank
# 200011_s_at                 Exemplar sequence  GenBank
# 200012_x_at                 Exemplar sequence  GenBank
# 200013_at                   Exemplar sequence  GenBank
# 200014_s_at                 Exemplar sequence  GenBank
# 200015_s_at                 Exemplar sequence  GenBank
# 200016_x_at                 Exemplar sequence  GenBank
# 200017_at                   Exemplar sequence  GenBank
# 200018_at                   Exemplar sequence  GenBank
# ⋮                           ⋮                  ⋮
# AFFX-HSAC07/X00351_5_at     Control sequence   Affymetrix Proprietary Database
# AFFX-HSAC07/X00351_M_at     Control sequence   Affymetrix Proprietary Database
# AFFX-hum_alu_at             Control sequence   Affymetrix Proprietary Database
# AFFX-HUMGAPDH/M33197_3_at   Control sequence   Affymetrix Proprietary Database
# AFFX-HUMGAPDH/M33197_5_at   Control sequence   Affymetrix Proprietary Database
# AFFX-HUMGAPDH/M33197_M_at   Control sequence   Affymetrix Proprietary Database
# AFFX-HUMISGF3A/M97935_3_at  Control sequence   Affymetrix Proprietary Database
# AFFX-HUMISGF3A/M97935_MA_at Control sequence   Affymetrix Proprietary Database
# AFFX-HUMISGF3A/M97935_MB_at Control sequence   Affymetrix Proprietary Database
# AFFX-HUMRGE/M10098_3_at     Control sequence   Affymetrix Proprietary Database
# AFFX-HUMRGE/M10098_5_at     Control sequence   Affymetrix Proprietary Database
# AFFX-HUMRGE/M10098_M_at     Control sequence   Affymetrix Proprietary Database
# AFFX-M27830_3_at            Control sequence   Affymetrix Proprietary Database
# AFFX-M27830_5_at            Control sequence   Affymetrix Proprietary Database
# AFFX-M27830_M_at            Control sequence   Affymetrix Proprietary Database
# AFFX-r2-Ec-bioB-3_at        Control sequence   Affymetrix Proprietary Database
# AFFX-r2-Ec-bioB-5_at        Control sequence   Affymetrix Proprietary Database
# AFFX-r2-Ec-bioB-M_at        Control sequence   Affymetrix Proprietary Database
# AFFX-r2-Ec-bioC-3_at        Control sequence   Affymetrix Proprietary Database
# AFFX-r2-Ec-bioC-5_at        Control sequence   Affymetrix Proprietary Database
# AFFX-r2-Ec-bioD-3_at        Control sequence   Affymetrix Proprietary Database
# AFFX-r2-Ec-bioD-5_at        Control sequence   Affymetrix Proprietary Database
# AFFX-r2-Hs18SrRNA-3_s_at    Control sequence   Affymetrix Proprietary Database
# AFFX-r2-Hs18SrRNA-5_at      Control sequence   Affymetrix Proprietary Database
# AFFX-r2-Hs18SrRNA-M_x_at    Control sequence   Affymetrix Proprietary Database
# AFFX-r2-Hs28SrRNA-3_at      Control sequence   Affymetrix Proprietary Database
# AFFX-r2-Hs28SrRNA-5_at      Control sequence   Affymetrix Proprietary Database
# AFFX-r2-Hs28SrRNA-M_at      Control sequence   Affymetrix Proprietary Database
# AFFX-r2-P1-cre-3_at         Control sequence   Affymetrix Proprietary Database
# AFFX-r2-P1-cre-5_at         Control sequence   Affymetrix Proprietary Database
#                             Target Description
# 1007_s_at                   U48705 /FEATURE=mRNA /DEFINITION=HSU48705 Human receptor tyrosine kinase DDR gene, complete cds
# 121_at                      X69699 /FEATURE= /DEFINITION=HSPAX8A H.sapiens Pax8 mRNA
# 1294_at                     L13852 /FEATURE= /DEFINITION=HUME1URP Homo sapiens ubiquitin-activating enzyme E1 related protein mRNA, complete cds
# 1405_i_at                   M21121 /FEATURE= /DEFINITION=HUMTCSM Human T cell-specific protein (RANTES) mRNA, complete cds
# 1487_at                     L38487 /FEATURE=mRNA /DEFINITION=HUMHERRA1 Human estrogen receptor-related protein (hERRa1) mRNA, 3' end, partial cds
# 1494_f_at                   M33318 /FEATURE=mRNA /DEFINITION=HUMCPIIA3A Human cytochrome P450IIA3 (CYP2A3) mRNA, complete cds
# 1598_g_at                   L13720 /FEATURE= /DEFINITION=HUMGAS Homo sapiens growth-arrest-specific protein (gas) mRNA, complete cds
# 160020_at                   Z48481 /FEATURE=cds /DEFINITION=HSMMPM1 H.sapiens mRNA for membrane-type matrix metalloproteinase 1 /NOTE=replacement of probe set 1301_s_at
# 1729_at                     L41690 /FEATURE= /DEFINITION=HUMTRADD Homo sapiens TNF receptor-1 associated protein (TRADD) mRNA, 3' end of cds
# 179_at                      U38980 /FEATURE= /DEFINITION=U38980 Human PMS2 related (hPMSR6) mRNA,  complete cds
# 1861_at                     U66879 /FEATURE= /DEFINITION=HSU66879 Human Bcl-2 binding component 6 (bbc6) mRNA, complete cds
# 200000_s_at                 gb:NM_006445.1 /DEF=Homo sapiens U5 snRNP-specific protein (220 kD), ortholog of S. cerevisiae Prp8p (PRP8), mRNA.  /FEA=mRNA /GEN=PRP8 /PROD=U5 snRNP-specific protein (220 kD), ortholog ofS. cerevisiae Prp8p /DB_XREF=gi:5453983 /UG=Hs.181368 U5 snRNP-specific protein (220 kD), ortholog of S. cerevisiae Prp8p /FL=gb:AB007510.1 gb:AF092565.1 gb:NM_006445.1
# AFFX-M27830_5_at            H. sapiens /GEN=28S rRNA /DB_XREF=gb:M27830.1 /NOTE=SIF corresponding to nucleotides 75-171 of gb:M27830.1 /DEF=Human 28S ribosomal RNA gene, complete cds.
# AFFX-M27830_M_at            H. sapiens /GEN=28S rRNA /DB_XREF=gb:M27830.1 /NOTE=SIF corresponding to nucleotides 529-1289 of gb:M27830.1 /DEF=Human 28S ribosomal RNA gene, complete cds.
# AFFX-r2-Ec-bioB-3_at        E. coli /GEN=bioB /DB_XREF=gb:J04423.1 /NOTE=SIF corresponding to nucleotides 2772-3004 of gb:J04423.1 /DEF=E.coli 7,8-diamino-pelargonic acid (bioA), biotin synthetase (bioB), 7-keto-8-amino-pelargonic acid synthetase (bioF), bioC protein, and dethiobiotin synthetase (bioD), complete cds.
# AFFX-r2-Ec-bioB-5_at        E. coli /GEN=bioB /DB_XREF=gb:J04423.1 /NOTE=SIF corresponding to nucleotides 2071-2304 of gb:J04423.1 /DEF=E.coli 7,8-diamino-pelargonic acid (bioA), biotin synthetase (bioB), 7-keto-8-amino-pelargonic acid synthetase (bioF), bioC protein, and dethiobiotin synthetase (bioD), complete cds.
# AFFX-r2-Ec-bioB-M_at        E. coli /GEN=bioB /DB_XREF=gb:J04423.1 /NOTE=SIF corresponding to nucleotides 2393-2682 of gb:J04423.1 /DEF=E.coli 7,8-diamino-pelargonic acid (bioA), biotin synthetase (bioB), 7-keto-8-amino-pelargonic acid synthetase (bioF), bioC protein, and dethiobiotin synthetase (bioD), complete cds.
# AFFX-r2-Ec-bioC-3_at        E. coli /GEN=bioC /DB_XREF=gb:J04423.1 /NOTE=SIF corresponding to nucleotides 4608-4883 of gb:J04423.1 /DEF=E.coli 7,8-diamino-pelargonic acid (bioA), biotin synthetase (bioB), 7-keto-8-amino-pelargonic acid synthetase (bioF), bioC protein, and dethiobiotin synthetase (bioD), complete cds.
# AFFX-r2-Ec-bioC-5_at        E. coli /GEN=bioC /DB_XREF=gb:J04423.1 /NOTE=SIF corresponding to nucleotides 4257-4573 of gb:J04423.1 /DEF=E.coli 7,8-diamino-pelargonic acid (bioA), biotin synthetase (bioB), 7-keto-8-amino-pelargonic acid synthetase (bioF), bioC protein, and dethiobiotin synthetase (bioD), complete cds.
# AFFX-r2-Ec-bioD-3_at        E. coli /GEN=bioD /DB_XREF=gb:J04423.1 /NOTE=SIF corresponding to nucleotides 5312-5559 of gb:J04423.1, not 100% identical /DEF=E.coli 7,8-diamino-pelargonic acid (bioA), biotin synthetase (bioB), 7-keto-8-amino-pelargonic acid synthetase (bioF), bioC protein, and dethiobiotin synthetase (bioD), complete cds.
# AFFX-r2-Ec-bioD-5_at        E. coli /GEN=bioD /DB_XREF=gb:J04423.1 /NOTE=SIF corresponding to nucleotides 5024-5244 of gb:J04423.1 /DEF=E.coli 7,8-diamino-pelargonic acid (bioA), biotin synthetase (bioB), 7-keto-8-amino-pelargonic acid synthetase (bioF), bioC protein, and dethiobiotin synthetase (bioD), complete cds.
# AFFX-r2-Hs18SrRNA-3_s_at    M10098.1 Human 18S rRNA sequence, length 1969 bases, 3 prime target bases 1293-1938
# AFFX-r2-Hs18SrRNA-5_at      M10098.1 Human 18S rRNA sequence, length 1969 bases, 5 prime target bases 1-646
# AFFX-r2-Hs18SrRNA-M_x_at    M10098.1 Human 18S rRNA sequence, length 1969 bases, middle target bases 647-1292
# AFFX-r2-Hs28SrRNA-3_at      M11167.1 Human 28S rRNA sequence, length 5025 bases, middle target bases 1666-3330
# AFFX-r2-Hs28SrRNA-5_at      M11167.1 Human 28S rRNA sequence, length 5025 bases, 5 prime target bases 1-1665
# AFFX-r2-Hs28SrRNA-M_at      M11167.1 Human 28S rRNA sequence, length 5025 bases, 3 prime target bases 3331-4995
# AFFX-r2-P1-cre-3_at         Bacteriophage P1 /GEN=cre /DB_XREF=gb:X03453.1 /NOTE=SIF corresponding to nucleotides 1032-1270 of gb:X03453.1 /DEF=Bacteriophage P1 cre gene for recombinase protein.
# AFFX-r2-P1-cre-5_at         Bacteriophage P1 /GEN=cre /DB_XREF=gb:X03453.1 /NOTE=SIF corresponding to nucleotides 581-1001 of gb:X03453.1 /DEF=Bacteriophage P1 cre gene for recombinase protein.
#                             Representative Public ID
# 1007_s_at                   U48705
# 121_at                      X69699
# 1294_at                     L13852
# 1405_i_at                   M21121
# 1487_at                     L38487
# 1494_f_at                   M33318
# 1598_g_at                   L13720
# 160020_at                   Z48481
# 1729_at                     L41690
# 179_at                      U38980
# 1861_at                     U66879
# 200000_s_at                 NM_006445
# 200001_at                   NM_001749
# 200002_at                   NM_007209
# 200003_s_at                 NM_000991
# 200004_at                   NM_001418
# 200005_at                   NM_003753
# 200006_at                   NM_007262
# 200007_at                   NM_003134
# 200008_s_at                 D13988
# 200009_at                   NM_001494
# 200010_at                   NM_000975
# 200011_s_at                 NM_001659
# 200012_x_at                 NM_000982
# 200013_at                   NM_000986
# 200014_s_at                 NM_004500
# 200015_s_at                 NM_004404
# 200016_x_at                 NM_002136
# 200017_at                   NM_002954
# 200018_at                   NM_001017
# ⋮                           ⋮
# AFFX-HSAC07/X00351_5_at     AFFX-HSAC07/X00351_5
# AFFX-HSAC07/X00351_M_at     AFFX-HSAC07/X00351_M
# AFFX-hum_alu_at             AFFX-hum_alu
# AFFX-HUMGAPDH/M33197_3_at   AFFX-HUMGAPDH/M33197_3
# AFFX-HUMGAPDH/M33197_5_at   AFFX-HUMGAPDH/M33197_5
# AFFX-HUMGAPDH/M33197_M_at   AFFX-HUMGAPDH/M33197_M
# AFFX-HUMISGF3A/M97935_3_at  AFFX-HUMISGF3A/M97935_3
# AFFX-HUMISGF3A/M97935_MA_at AFFX-HUMISGF3A/M97935_MA
# AFFX-HUMISGF3A/M97935_MB_at AFFX-HUMISGF3A/M97935_MB
# AFFX-HUMRGE/M10098_3_at     AFFX-HUMRGE/M10098_3
# AFFX-HUMRGE/M10098_5_at     AFFX-HUMRGE/M10098_5
# AFFX-HUMRGE/M10098_M_at     AFFX-HUMRGE/M10098_M
# AFFX-M27830_3_at            AFFX-M27830_3
# AFFX-M27830_5_at            AFFX-M27830_5
# AFFX-M27830_M_at            AFFX-M27830_M
# AFFX-r2-Ec-bioB-3_at        AFFX-r2-Ec-bioB-3
# AFFX-r2-Ec-bioB-5_at        AFFX-r2-Ec-bioB-5
# AFFX-r2-Ec-bioB-M_at        AFFX-r2-Ec-bioB-M
# AFFX-r2-Ec-bioC-3_at        AFFX-r2-Ec-bioC-3
# AFFX-r2-Ec-bioC-5_at        AFFX-r2-Ec-bioC-5
# AFFX-r2-Ec-bioD-3_at        AFFX-r2-Ec-bioD-3
# AFFX-r2-Ec-bioD-5_at        AFFX-r2-Ec-bioD-5
# AFFX-r2-Hs18SrRNA-3_s_at    AFFX-r2-Hs18SrRNA-3
# AFFX-r2-Hs18SrRNA-5_at      AFFX-r2-Hs18SrRNA-5
# AFFX-r2-Hs18SrRNA-M_x_at    AFFX-r2-Hs18SrRNA-M
# AFFX-r2-Hs28SrRNA-3_at      AFFX-r2-Hs28SrRNA-3
# AFFX-r2-Hs28SrRNA-5_at      AFFX-r2-Hs28SrRNA-5
# AFFX-r2-Hs28SrRNA-M_at      AFFX-r2-Hs28SrRNA-M
# AFFX-r2-P1-cre-3_at         AFFX-r2-P1-cre-3
# AFFX-r2-P1-cre-5_at         AFFX-r2-P1-cre-5
#                             Gene Title
# 1007_s_at                   discoidin domain receptor tyrosine kinase 1 /// microRNA 4640
# 121_at                      paired box 8
# 1294_at                     microRNA 5193 /// ubiquitin-like modifier activating enzyme 7
# 1405_i_at                   chemokine (C-C motif) ligand 5
# 1487_at                     estrogen-related receptor alpha
# 1494_f_at                   cytochrome P450, family 2, subfamily A, polypeptide 6
# 1598_g_at                   growth arrest-specific 6
# 160020_at                   matrix metallopeptidase 14 (membrane-inserted)
# 1729_at                     TNFRSF1A-associated via death domain
# 179_at                      DTX2P1-UPK3BP1-PMS2P11 readthrough transcribed pseudogene
# 1861_at                     BCL2-associated agonist of cell death
# 200000_s_at                 pre-mRNA processing factor 8
# 200001_at                   calpain, small subunit 1
# 200002_at                   ribosomal protein L35
# 200003_s_at                 microRNA 6805 /// ribosomal protein L28
# 200004_at                   eukaryotic translation initiation factor 4 gamma, 2
# 200005_at                   eukaryotic translation initiation factor 3, subunit D
# 200006_at                   parkinson protein 7
# 200007_at                   signal recognition particle 14kDa (homologous Alu RNA binding protein)
# 200008_s_at                 GDP dissociation inhibitor 2
# 200009_at                   GDP dissociation inhibitor 2
# 200010_at                   ribosomal protein L11
# 200011_s_at                 ADP-ribosylation factor 3
# 200012_x_at                 ribosomal protein L21 /// ribosomal protein L21 pseudogene 28 /// small nucleolar RNA, H/ACA box 27 /// small nucleolar RNA, C/D box 102
# 200013_at                   ribosomal protein L24
# 200014_s_at                 heterogeneous nuclear ribonucleoprotein C (C1/C2)
# 200015_s_at                 septin 2
# 200016_x_at                 heterogeneous nuclear ribonucleoprotein A1 /// heterogeneous nuclear ribonucleoprotein A1 pseudogene 10
# 200017_at                   ribosomal protein S27a
# 200018_at                   uncharacterized LOC100508408 /// ribosomal protein S13 /// small nucleolar RNA, C/D box 14B
# ⋮                           ⋮
# AFFX-HSAC07/X00351_5_at     actin, beta
# AFFX-HSAC07/X00351_M_at     actin, beta
# AFFX-hum_alu_at
# ...
# AFFX-r2-Ec-bioD-5_at
# AFFX-r2-Hs18SrRNA-3_s_at
# AFFX-r2-Hs18SrRNA-5_at
# AFFX-r2-Hs18SrRNA-M_x_at
# AFFX-r2-Hs28SrRNA-3_at
# AFFX-r2-Hs28SrRNA-5_at
# AFFX-r2-Hs28SrRNA-M_at
# AFFX-r2-P1-cre-3_at
# AFFX-r2-P1-cre-5_at

# %% [markdown]
# Verifique e escolha as colunas que você deseja. Nesse caso iremos usar as seguintes colunas: `"GB_ACC"`, `"Gene Symbol"`, `"ENTREZ_GENE_ID"`, `"RefSeq Transcript ID"`.

# %%
anno <- select(anno, "GB_ACC", "Gene Symbol", "ENTREZ_GENE_ID", "RefSeq Transcript ID")
fit2$genes <- anno
topTable(fit2)
# Out:
#             GB_ACC    Gene.Symbol               ENTREZ_GENE_ID
# 204220_at   NM_004877 GMFG                      9535
# 201693_s_at AV733950  EGR1                      1958
# 202659_at   NM_002801 PSMB10                    5699
# 201694_s_at NM_001964 EGR1                      1958
# 200653_s_at M27319    CALM1 /// CALM2 /// CALM3 801 /// 805 /// 808
# 202303_x_at NM_003601 SMARCA5                   8467
# 208743_s_at BC001359  YWHAB                     7529
# 209572_s_at AF080227  EED                       8726
# 213620_s_at AA126728  ICAM2                     3384
# 213139_at   AI572079  SNAI2                     6591
#             RefSeq.Transcript.ID
# 204220_at   NM_004877 /// XM_005259440
# 201693_s_at NM_001964
# 202659_at   NM_002801
# 201694_s_at NM_001964
# 200653_s_at NM_001166106 /// NM_001743 /// NM_005184 /// NM_006888 /// XM_006720258
# 202303_x_at NM_003601
# 208743_s_at NM_003404 /// NM_139323
# 209572_s_at NM_003797 /// NM_152991 /// XM_005274373 /// XM_006718730 /// XM_006718731 /// XR_247215
# 213620_s_at NM_000873 /// NM_001099786 /// NM_001099787 /// NM_001099788 /// NM_001099789
# 213139_at   NM_003068
#             logFC      AveExpr   t          P.Value      adj.P.Val    B
# 204220_at    1.2338294  9.241031  10.719353 1.821613e-09 1.333217e-05 11.801993
# 201693_s_at -1.7042057  7.413416 -10.602572 2.178104e-09 1.333217e-05 11.637477
# 202659_at    1.0187782  9.643952   9.764569 8.201093e-09 2.185198e-05 10.407000
# 201694_s_at -2.7719768  9.824949  -9.610962 1.054693e-08 2.185198e-05 10.171632
# 200653_s_at  0.7697343  9.010519   9.522224 1.221193e-08 2.185198e-05 10.034232
# 202303_x_at  0.6836935  8.636306   9.463128 1.347102e-08 2.185198e-05  9.942143
# 208743_s_at  0.9388022  9.434581   9.438272 1.404038e-08 2.185198e-05  9.903269
# 209572_s_at  1.1675780  8.599309   9.407221 1.478706e-08 2.185198e-05  9.854590
# 213620_s_at  1.6759957 12.002049   9.302027 1.763959e-08 2.185198e-05  9.688704
# 213139_at    1.4177989 10.048226   9.294983 1.785001e-08 2.185198e-05  9.677543

# %% [markdown]
# A função *Volcano Plot* é uma maneira comum de visualizar os resultados de uma análise de DE. O eixo x mostra a mudança log-fold e o eixo y é alguma medida de significância estatística, que neste caso é o log-odds, ou estatística "B". Uma forma característica de "vulcão" deve ser vista.
#
# Primeiro, criamos um quadro de dados que podemos visualizar no `ggplot2`. Especificar o argumento número para `topTable` cria uma tabela contendo resultados de teste de todos os genes. Também colocamos os IDs de sonda como uma coluna em vez de nomes de linha.

# %%
full_results <- topTable(fit2, number=Inf)
full_results <- tibble::rownames_to_column(full_results,"ID")

# %% [markdown]
# O gráfico básico é então criado com os comandos abaixo:

# %%
## Make sure you have ggplot2 loaded
library(ggplot2)
ggplot(full_results,aes(x = logFC, y=B)) + geom_point()
# Out:
# plot without title

# %% [markdown]
# A flexibilidade do `ggplot2` nos permite rotular automaticamente pontos no gráfico que podem ser de interesse. Por exemplo, genes que atendem a um corte específico de valor-p e mudança de log-fold. Com o código abaixo, os valores de `p_cutoff` e `fc_cutoff` podem ser alterados conforme desejado.

# %%
## change according to your needs
p_cutoff <- 0.05
fc_cutoff <- 1

full_results %>%
  mutate(Significant = adj.P.Val < p_cutoff, abs(logFC) > fc_cutoff ) %>%
  ggplot(aes(x = logFC, y = B, col=Significant)) + geom_point()
# Out:
# plot without title

# %% [markdown]
# Além disso, podemos rotular a identidade de alguns genes. Abaixo, definimos um limite para os principais genes "N" que queremos rotular e rotulamos cada gene de acordo com seu Símbolo. Isso pode ser útil para identificar rapidamente genes de interesse em nosso gráfico.

# %%
library(ggrepel)
p_cutoff <- 0.05
fc_cutoff <- 1
topN <- 20

full_results %>%
    mutate(Significant = adj.P.Val < p_cutoff, abs(logFC) > fc_cutoff ) %>%
    mutate(Rank = 1:n(), Label = ifelse(Rank < topN, Gene.Symbol,"")) %>%
    ggplot(aes(x = logFC, y = B, col=Significant,label=Label)) + geom_point() + geom_text_repel(col="black")
# Out:
# Warning message:
# “ggrepel: 4 unlabeled data points (too many overlaps). Consider increasing max.overlaps”
# plot without title

# %% [markdown]
# ## Filtrando e exportando a tabela de resultados
#
# A função filter do `dplyr` oferece uma maneira conveniente de interrogar a tabela de resultados.

# %%
## Get the results for particular gene of interest
filter(full_results, Gene.Symbol == "GATM")
# Out:
#   ID          GB_ACC    Gene.Symbol ENTREZ_GENE_ID
# 1 216733_s_at X86401    GATM        2628
# 2 203178_at   NM_001482 GATM        2628
#   RefSeq.Transcript.ID                                logFC     AveExpr
# 1 NM_001482 /// XR_424635 /// XR_429525 /// XR_433091 -1.871770 10.902036
# 2 NM_001482 /// XR_424635 /// XR_429525 /// XR_433091 -1.530048  9.154392
#   t         P.Value     adj.P.Val  B
# 1 -3.237493 0.004360822 0.01962227 -2.294502
# 2 -3.013304 0.007184516 0.02751285 -2.766811

# %% [markdown]
# Ou com partes do nome:

# %%
## Get results for genes with TP53 in the name
filter(full_results, grepl("TP53", Gene.Symbol))
# Out:
#    ID          GB_ACC    Gene.Symbol
# 1  209917_s_at BC002709  TP53TG1
# 2  203421_at   NM_006034 TP53I11
# 3  216919_at   U79302    TP53I11
# 4  203050_at   NM_005657 TP53BP1
# 5  210241_s_at AB007458  TP53TG1
# 6  203120_at   NM_005426 TP53BP2
# 7  210886_x_at AB007457  TP53TG1
# 8  213266_at   BF592982  TP53BP1
# 9  220167_s_at NM_015369 TP53TG3 /// TP53TG3B /// TP53TG3C /// TP53TG3D
# 10 210609_s_at BC000474  TP53I3
#    ENTREZ_GENE_ID
# 1  11257
# 2  9537
# 3  9537
# 4  7158
# 5  11257
# 6  7159
# 7  11257
# 8  7158
# 9  24150 /// 653550 /// 729264 /// 729355
# 10 9540
#    RefSeq.Transcript.ID
# 1  NM_007233 /// NR_015381
# 2  NM_001076787 /// NM_001258320 /// NM_001258321 /// NM_001258322 /// NM_001258323 /// NM_001258324 /// NM_006034 /// XM_005253227 /// XM_005253229 /// XM_006718387 /// XR_242833 /// XR_428864
# 3  NM_001076787 /// NM_001258320 /// NM_001258321 /// NM_001258322 /// NM_001258323 /// NM_001258324 /// NM_006034 /// XM_005253227 /// XM_005253229 /// XM_006718387 /// XR_242833 /// XR_428864
# 4  NM_001141979 /// NM_001141980 /// NM_005657 /// XM_005254634 /// XM_005254635 /// XM_006720666
# 5  NM_007233 /// NR_015381
# 6  NM_001031685 /// NM_005426 /// XM_005273246
# 7  NM_007233 /// NR_015381
# 8  NM_001141979 /// NM_001141980 /// NM_005657 /// XM_005254634 /// XM_005254635 /// XM_006720666
# 9  NM_001099687 /// NM_001205259 /// NM_001205260 /// NM_001205265 /// NM_001243722 /// NM_001267813 /// NM_015369 /// NM_016212 /// NR_110886 /// NR_110897 /// NR_110898 /// NR_110910 /// NR_110911 /// NR_110914 /// XM_006721026 /// XM_006721027 /// XM_006721074 /// XM_006721075 /// XM_006721084
# 10 NM_001206802 /// NM_004881 /// NM_147184 /// XM_005264650 /// XM_006712150
#    logFC       AveExpr  t          P.Value     adj.P.Val  B
# 1   0.37650934 8.076034  3.1702557 0.005068632 0.02157517 -2.437196
# 2   0.31558872 8.092472  2.6801373 0.014864339 0.04644939 -3.446413
# 3  -0.19579077 7.136381 -2.6477598 0.015933459 0.04870347 -3.510719
# 4   0.17899130 9.618734  2.3228895 0.031516711 0.07894753 -4.134902
# 5   0.22697682 7.506065  1.8537559 0.079467508 0.15622952 -4.952041
# 6   0.21151643 9.027983  1.3678749 0.187414734 0.29796509 -5.659399
# 7   0.19079908 8.767360  1.3098423 0.205965432 0.31916820 -5.732574
# 8  -0.05092451 9.663403 -0.5331723 0.600135548 0.70050147 -6.434382
# 9  -0.11576465 7.877122 -0.4462436 0.660497527 0.74806279 -6.477794
# 10  0.05715550 9.391506  0.3070166 0.762191618 0.82941216 -6.531541

# %% [markdown]
# Também podemos filtrar de acordo com os limites de valor-p (ajustado) e LogFC:

# %%
p_cutoff <- 0.05
fc_cutoff <- 1

filter(full_results, adj.P.Val < 0.05, abs(logFC) > 1)
# Out:
#     ID          GB_ACC
# 1   204220_at   NM_004877
# 2   201693_s_at AV733950
# 3   202659_at   NM_002801
# 4   201694_s_at NM_001964
# 5   209572_s_at AF080227
# 6   213620_s_at AA126728
# 7   213139_at   AI572079
# 8   201464_x_at BG491844
# 9   202083_s_at AI017770
# 10  205081_at   NM_001311
# 11  204683_at   NM_000873
# 12  201531_at   NM_003407
# 13  204975_at   NM_001424
# 14  210657_s_at U88870
# 15  219243_at   NM_018326
# 16  219315_s_at NM_024600
# 17  218611_at   NM_016545
# 18  219134_at   NM_022159
# 19  209355_s_at AB000889
# 20  205756_s_at NM_000132
# 21  203753_at   NM_003199
# 22  219436_s_at NM_016242
# 23  200760_s_at N92494
# 24  208981_at   AA702701
# 25  208983_s_at M37780
# 26  220134_x_at NM_018166
# 27  221710_x_at BC006241
# 28  201466_s_at NM_002228
# 29  204610_s_at NM_006848
# 30  204021_s_at NM_005859
# ⋮   ⋮           ⋮
# 387 206343_s_at NM_013959
# 388 210343_s_at AF124373
# 389 220135_s_at NM_014270
# 390 210402_at   U03884
# 391 204981_at   NM_002555
# 392 221305_s_at NM_019076
# 393 206515_at   NM_000896
# 394 201562_s_at NM_003104
# 395 219796_s_at NM_021924
# 396 202833_s_at NM_000295
# 397 205750_at   NM_004332
# 398 204508_s_at BC001012
# 399 219962_at   NM_021804
# 400 203924_at   NM_000846
# 401 206054_at   NM_000893
# 402 206172_at   NM_000640
# 403 210289_at   AB013094
# 404 204130_at   NM_000196
# 405 205347_s_at NM_021992
# 406 208596_s_at NM_019093
# 407 220503_at   AF260824
# 408 211416_x_at L20492
# 409 205892_s_at NM_001443
# 410 209977_at   M74220
# 411 215363_x_at AW168915
# 412 204409_s_at BC005248
# 413 203382_s_at NM_000041
# 414 206522_at   NM_004668
# 415 203477_at   NM_001855
# 416 215125_s_at AV691323
#     Gene.Symbol
# 1   GMFG
# 2   EGR1
# 3   PSMB10
# 4   EGR1
# 5   EED
# 6   ICAM2
# 7   SNAI2
# 8   JUN
# 9   SEC14L1
# 10  CRIP1
# 11  ICAM2
# 12  ZFP36
# 13  EMP2
# 14  SEPT4
# 15  GIMAP4
# 16  TMEM204
# 17  IER5
# 18  ELTD1
# 19  PPAP2B
# 20  F8
# 21  TCF4
# 22  EMCN
# 23  ARL6IP5
# 24  PECAM1
# 25  PECAM1
# 26  EVA1B
# 27  EVA1B
# 28  JUN
# 29  CCDC85B
# 30  PURA
# ⋮   ⋮
# 387 NRG1
# 388 SLC22A6
# 389 SLC7A9
# 390 KCNJ1
# 391 SLC22A18
# 392 UGT1A1 /// UGT1A3 /// UGT1A5 /// UGT1A8 /// UGT1A9
# 393 CYP4F3
# 394 SORD
# 395 CDHR5
# 396 SERPINA1
# 397 BPHL
# 398 CA12
# 399 ACE2
# 400 GSTA1
# 401 KNG1
# 402 IL13RA2
# 403 NAT8 /// NAT8B
# 404 HSD11B2
# 405 TMSB15A /// TMSB15B
# 406 UGT1A1 /// UGT1A10 /// UGT1A3 /// UGT1A4 /// UGT1A5 /// UGT1A6 /// UGT1A7 /// UGT1A8 /// UGT1A9
# 407 SLC13A1
# 408 GGTLC1
# 409 FABP1
# 410 PLG
# 411 FOLH1 /// FOLH1B
# 412 EIF1AY
# 413 APOE
# 414 MGAM
# 415 COL15A1
# 416 UGT1A1 /// UGT1A10 /// UGT1A3 /// UGT1A4 /// UGT1A5 /// UGT1A6 /// UGT1A7 /// UGT1A8 /// UGT1A9
#     ENTREZ_GENE_ID
# 1   9535
# 2   1958
# 3   5699
# 4   1958
# 5   8726
# 6   3384
# 7   6591
# 8   3725
# 9   6397
# 10  1396
# 11  3384
# 12  7538
# 13  2013
# 14  5414
# 15  55303
# 16  79652
# 17  51278
# 18  64123
# 19  8613
# 20  2157
# 21  6925
# 22  51705
# 23  10550
# 24  5175
# 25  5175
# 26  55194
# 27  55194
# 28  3725
# 29  11007
# 30  5813
# ⋮   ⋮
# 387 3084
# 388 9356
# 389 11136
# 390 3758
# 391 5002
# 392 54576 /// 54579 /// 54600 /// 54658 /// 54659
# 393 4051
# 394 6652
# 395 53841
# 396 5265
# 397 670
# 398 771
# 399 59272
# 400 2938
# 401 3827
# 402 3598
# 403 9027 /// 51471
# 404 3291
# 405 11013 /// 286527
# 406 54575 /// 54576 /// 54577 /// 54578 /// 54579 /// 54600 /// 54657 /// 54658 /// 54659
# 407 6561
# 408 92086
# 409 2168
# 410 5340
# 411 2346 /// 219595
# 412 9086
# 413 348
# 414 8972
# 415 1306
# 416 54575 /// 54576 /// 54577 /// 54578 /// 54579 /// 54600 /// 54657 /// 54658 /// 54659
#     RefSeq.Transcript.ID
# 1   NM_004877 /// XM_005259440
# 2   NM_001964
# 3   NM_002801
# 4   NM_001964
# 5   NM_003797 /// NM_152991 /// XM_005274373 /// XM_006718730 /// XM_006718731 /// XR_247215
# 6   NM_000873 /// NM_001099786 /// NM_001099787 /// NM_001099788 /// NM_001099789
# 7   NM_003068
# 8   NM_002228
# 9   NM_001039573 /// NM_001143998 /// NM_001143999 /// NM_001144001 /// NM_001204408 /// NM_001204410 /// NM_003003
# 10  NM_001311
# 11  NM_000873 /// NM_001099786 /// NM_001099787 /// NM_001099788 /// NM_001099789
# 12  NM_003407
# 13  NM_001424 /// XM_006720864
# 14  NM_001198713 /// NM_001256782 /// NM_001256822 /// NM_004574 /// NM_080415 /// NM_080416 /// NM_080417 /// NR_037155 /// NR_104196 /// NR_104197 /// XM_006721949 /// XM_006721950 /// XM_006721951 /// XM_006721952 /// XM_006721953 /// XM_006721954 /// XM_006721955
# 27   1.046293  9.033187   7.521183 4.312328e-07 9.101986e-05  6.642931
# 28  -1.152244  7.975422  -7.479368 4.671669e-07 9.457522e-05  6.565853
# 29   1.369140  9.046386   7.474824 4.712538e-07 9.457522e-05  6.557463
# 30   1.019245  7.937830   7.399912 5.442555e-07 1.038190e-04  6.418679
# ⋮   ⋮         ⋮         ⋮          ⋮            ⋮            ⋮
# 387 -1.016501  6.347704 -2.801596  0.01143153   0.03847807   -3.202249
# 388 -1.654990  7.959016 -2.797216  0.01154089   0.03878220   -3.211130
# 389 -1.929020  9.932542 -2.791623  0.01168201   0.03914897   -3.222463
# 390 -1.504404  7.934658 -2.789098  0.01174627   0.03931051   -3.227577
# 391 -1.035722  8.997488 -2.786368  0.01181613   0.03945800   -3.233105
# 392 -1.584402  6.515146 -2.780192  0.01197562   0.03982765   -3.245600
# 393 -1.777933  7.033450 -2.779121  0.01200349   0.03988781   -3.247766
# 394 -1.212893  8.396750 -2.777737  0.01203957   0.03997004   -3.250562
# 395 -1.140199  6.645427 -2.776766  0.01206498   0.04001610   -3.252526
# 396 -1.111372  9.208421 -2.765461  0.01236437   0.04070404   -3.275356
# 397 -1.009803  7.793937 -2.754054  0.01267369   0.04144287   -3.298354
# 398 -1.221562  8.668151 -2.752382  0.01271964   0.04154584   -3.301722
# 399 -1.811677  7.628491 -2.749214  0.01280715   0.04174609   -3.308101
# 400 -1.989504 10.928445 -2.735572  0.01319059   0.04257294   -3.335534
# 401 -2.044718  8.962754 -2.726078  0.01346388   0.04323840   -3.354592
# 402  1.162252 11.284671  2.715158  0.01378489   0.04400382   -3.376478
# 403 -1.656311 11.229795 -2.713637  0.01383017   0.04410635   -3.379523
# 404 -1.621121  7.662841 -2.707387  0.01401779   0.04452666   -3.392031
# 405  1.294769  9.806218  2.704285  0.01411177   0.04476711   -3.398232
# 406 -1.631055  9.153962 -2.700115  0.01423908   0.04504258   -3.406566
# 407 -1.958222  7.313582 -2.693016  0.01445836   0.04555964   -3.420741
# 408 -1.058004  8.430367 -2.692043  0.01448864   0.04559465   -3.422681
# 409 -2.071351  8.128849 -2.676559  0.01497906   0.04667182   -3.453537
# 410 -1.754457  8.842504 -2.675495  0.01501332   0.04676668   -3.455654
# 411 -1.100923  7.440678 -2.671314  0.01514872   0.04706868   -3.463971
# 412  2.180081  6.174330  2.642937  0.01609883   0.04903754   -3.520268
# 413 -1.475102  9.512102 -2.640108  0.01619657   0.04926240   -3.525865
# 414 -1.743847  8.277897 -2.634468  0.01639318   0.04969389   -3.537018
# 415  1.081371  7.342934  2.634199  0.01640262   0.04970035   -3.537550
# 416 -1.935491  9.516912 -2.630282  0.01654055   0.04993573   -3.545288

# %% [markdown]
# Esses resultados podem ser exportados com a função `write_csv`.

# %%
library(readr)
filter(full_results, adj.P.Val < 0.05, abs(logFC) > 1) %>%
  write_csv(path="filtered_de_results.csv")

# %% [markdown]
# # Visualização adicional
#
# ## Mapas de calor de genes selecionados
#
# O R e o Bioconductor têm muitos pacotes para criar *heatmaps*. Os mais populares no momento são `ComplexHeatmap` e `pheatmap` (que usaremos aqui).
#
# Criar o *heatmap* é bastante simples. Há uma função `pheatmap` dentro da biblioteca `pheatmap`, e ela só precisa saber a matriz de valores que você deseja plotar (digamos `gene_matrix`):
#
# ```R
# ### example code
# library(pheatmap)
# pheatmap(gene_matrix)
# ```
# No entanto, existem muitas maneiras diferentes de construir essa matriz, dependendo do que você deseja visualizar no gráfico. Consideraremos algumas opções abaixo.

# %% [markdown]
# ### Genes mais diferencialmente expressos
#
# Já criamos uma tabela de resultados de expressão diferencial, que é classificada de acordo com a significância estatística.
#
# Para visualizar os genes mais diferencialmente expressos, primeiro precisamos extrair o ID deles. Esses IDs devem corresponder às linhas na matriz de expressão.
#
# No código abaixo, introduzimos uma nova coluna nos resultados que apenas atribui um número de linha a cada gene. Em seguida, filtramos para retornar dados para os principais resultados N. A função `pull` é usada para extrair a coluna ID como uma variável.

# %%
## Use to top 20 genes for illustration

topN <- 20
##
ids_of_interest <- mutate(full_results, Rank = 1:n()) %>%
  filter(Rank < topN) %>%
  pull(ID)

# %% [markdown]
# Para rotular o mapa de calor de maneira útil, extraímos os símbolos de genes correspondentes.

# %%
gene_names <- mutate(full_results, Rank = 1:n()) %>%
  filter(Rank < topN) %>%
  pull(Gene.Symbol)

# %% [markdown]
# Os valores de expressão para os IDs que recuperamos podem ser obtidos usando a notação [..] para indexar a matriz de expressão.

# %%
## Get the rows corresponding to ids_of_interest and all columns
gene_matrix <- exprs(gse)[ids_of_interest,]

# %% [markdown]
# Agora fazemos o mapa de calor. Um esquema de cores padrão é usado, mas pode ser alterado por meio dos argumentos. **Por favor, não use vermelho e verde. Não é acessível a todos.**

# %%
pheatmap(gene_matrix,
     labels_row = gene_names)
# Out:
# plot without title

# %% [markdown]
# Muitas vezes é preferível escalar cada linha para destacar as diferenças em cada gene em todo o conjunto de dados.

# %%
pheatmap(gene_matrix,
     labels_row = gene_names,
     scale="row")
# Out:
# plot without title

# %% [markdown]
# Se você quiser anotar as amostras, só colocar:

# %%
pheatmap(gene_matrix,
     labels_row = gene_names,
     scale="row", annotation_col=sampleInfo)
# Out:
# plot without title

# %% [markdown]
# Agora as amostras controle estão bem separadas em relação as de Nefroesclerose (é bem provável que você não consiga visualizar, pois a parte gráfica do Colab/R não é muito boa).
#
# >*Estou procurando formas de construir o heatmap em uma maior resolução, modificando o código de executar a figura. Deverá estar pronto em uma próxima atualização.*)

# %% [markdown]
# ## Genes de interesse definidos pelo usuário
#
# O procedimento é semelhante ao acima se você tem sua própria lista de genes (por exemplo, genes de um estudo anterior). A função `%in%` é usada para identificar linhas cujo `Symbol` corresponde a qualquer membro de `my_genes`. Aqui criamos `my_genes` manualmente. Se você quiser plotar os genes pertencentes a um termo GO específico, pode ser mais eficiente seguir a seção abaixo.
#
# Dependendo da tecnologia utilizada, pode haver várias correspondências para um gene específico; então poderíamos acabar com mais IDs do que genes. Portanto, repetimos a filtragem e puxamos a coluna `Symbol` para garantir que possamos rotular as linhas do *heatmap*.
#
# Usaremos os genes abaixo, mas fique a vontade para trocar os símbolos pelos genes que deseja verificar. Apenas lembre que os genes escolhidos podem não estar diferencialmente expressos, ou até mesmo serem expressos.

# %%
my_genes <- c("SLC2A4", "IGF1", "GATM", "SLC6A8", "AKT1", "AKT2", "AKT3", "PSMB5", "PSMD3", "SGK1", "PRPS1", "CKB", "CKM", "CKMT1A", "CKMT1B", "CKMT2", "SLC16A12")

# %% [markdown]
# Agora vamos criar um *dataframe* chamado `ids_of_interest` e vamos retirar os genes da tabela `full_results` que correspondem ao genes que estão descritos em `my_genes`:

# %%
ids_of_interest <-  filter(full_results,Gene.Symbol %in% my_genes) %>%
    pull(ID)
gene_names <-  filter(full_results,Gene.Symbol %in% my_genes) %>%
    pull(Gene.Symbol)

# %% [markdown]
# Agora construiremos a matriz para o *heatmap*:

# %%
gene_matrix <- exprs(gse)[ids_of_interest,]

# %% [markdown]
# E construiremos o *heatmap* da expressão desse genes de interesse, já usando a anotação das amostras presentes em `sampleInfo`:

# %%
pheatmap(gene_matrix,
         labels_row = gene_names,
         scale="row", annotation_col=sampleInfo)
# Out:
# plot without title

# %% [markdown]
# ## Genes específicos de uma Via ou Processo metabólico
#
# Existem pacotes de anotação do Bioconductor para vários organismos que permitem uma fácil conversão entre diferentes esquemas de ID. Neste caso de uso específico, podemos recuperar os nomes dos genes pertencentes a um determinado caminho.
#
# Você pode verificar quais pacotes estão disponíveis na página do Bioconductor (procure pelos pacotes nomeados como org.XX.XX.db).

# %%
library(org.Hs.eg.db)
# Out:
# Loading required package: AnnotationDbi
#
# Loading required package: stats4
#
# Loading required package: IRanges
#
# Loading required package: S4Vectors
#
#
# Attaching package: ‘S4Vectors’
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     first, rename
#
#
# The following object is masked from ‘package:utils’:
#
#     findMatches
#
#
# The following objects are masked from ‘package:base’:
#
#     expand.grid, I, unname
#
#
#
# Attaching package: ‘IRanges’
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     collapse, desc, slice
#
#
#
# Attaching package: ‘AnnotationDbi’
#
#
# The following object is masked from ‘package:dplyr’:
#
#     select

# %% [markdown]
# Vamos selecionar o [GO:0006600](https://www.ebi.ac.uk/QuickGO/term/GO:0006600), que corresponde ao Metabolismo da Creatina.

# %%
anno <- AnnotationDbi::select(org.Hs.eg.db,
                              columns="SYMBOL",
                              keys="GO:0006600",
                              keytype="GO")
anno
# Out:
# 'select()' returned 1:many mapping between keys and columns
#   GO         EVIDENCE ONTOLOGY SYMBOL
# 1 GO:0006600 TAS      BP       GAMT
# 2 GO:0006600 IMP      BP       GATM
# 3 GO:0006600 TAS      BP       SLC6A8
# 4 GO:0006600 IEA      BP       FKRP

# %% [markdown]
# Agora vamos atualizar a nossa lista `my_genes`como os genes que estejam associados a este GO:

# %%
my_genes <- pull(anno, SYMBOL)

# %% [markdown]
# Atualizaremos também a nossa lista `ids_of_interest`, filtrando a partir dos genes que estavam em `my_genes`. E depois iremos retirar os nomes desses genes.

# %%
ids_of_interest <-  filter(full_results,Gene.Symbol %in% my_genes) %>%
    pull(ID)

gene_names <-  filter(full_results,Gene.Symbol %in% my_genes) %>%
    pull(Gene.Symbol)

# %% [markdown]
# Agora é só criar a nova matriz e construir o *heatmap* com os genes que estão associados a essa ontologia:

# %%
gene_matrix <- exprs(gse)[ids_of_interest,]
pheatmap(gene_matrix,
         labels_row = gene_names,
         scale="row", annotation_col=sampleInfo)
# Out:
# plot without title

# %% [markdown]
# ## Considerações finais
#
# Há uma série de outras análises que podem ser realizadas e estão descritas no tutorial original. Não esqueça de citar ele, não esta versão, que tem fins apenas didáticos.
